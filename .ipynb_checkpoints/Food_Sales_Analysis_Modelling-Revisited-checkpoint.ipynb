# %% [markdown]
# <a href="https://colab.research.google.com/github/JosephPLim/food_sales_predictions/blob/main/Food_Sales_AnalysisII.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <center>Food Sales Analysis Modeling Revisited </center>
#
# Joseph Lim

# %%
#Basic Pandas/Numpy
import numpy as np
import pandas as pd

#Data Visualization
import seaborn as sns
import matplotlib.pyplot as plt

#ML Preprocessing
from sklearn.preprocessing import StandardScaler, OneHotEncoder, OrdinalEncoder
from sklearn.model_selection import train_test_split
from sklearn.compose import make_column_selector, make_column_transformer
from sklearn.impute import SimpleImputer
from sklearn.pipeline import make_pipeline
from sklearn import set_config
set_config(display='diagram')

#Regression Libraries
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import BaggingRegressor, RandomForestRegressor
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

#TensorFlow/Keras
from tensorflow.keras import Sequential
from tensorflow.keras import metrics
from tensorflow.keras.layers import Dense, Dropout

#Post-Analysis
import joblib

#linking to Google Drive
#from google.colab import drive
#drive.mount("/content/drive")
# Out:
# 2023-04-21 00:03:11.330398: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)
pd.set_option('display.float_format', lambda x: f"{x:,.2f}")

# %% [markdown]
# Data Dictionary
#
# | Category                  | Data Type | Feature Type | Description                                                                                         |
# |---------------------------|-----------|--------------|-----------------------------------------------------------------------------------------------------|
# | Item_Identifier           | object    | Numeric      | Unique product ID                                                                                   |
# | Item_Weight               | float     | Numeric      | Weight of product                                                                                   |
# | Item_Fat_Content          | object    | Nominal      | Whether the product is low fat or regular                                                           |
# | Item_Visibility           | float     | Numeric      | The percentage of total display area of all products in a store allocated to the particular product |
# | Item_Type                 | object    | Nominal      | The category to which the product belongs                                                           |
# | Item_MRP                  | float     | Numeric      | Maximum Retail Price (list price) of the product                                                    |
# | Outlet_Identifier         | object    | Nominal      | Unique store ID                                                                                     |
# | Outlet_Establishment_Year | int       | Ordinal      | The year in which store was established                                                             |
# | Outlet_Size               | object    | Ordinal      | The size of the store in terms of ground area covered                                               |
# | Outlet_Location_Type      | object    | Ordinal      | The type of area in which the store is located                                                      |
# | Outlet_Type               | object    | Nominal      | Whether the outlet is a grocery store or some sort of supermarket                                   |
# | Item_Outlet_Sales         | float     | TARGET       | Sales of the product in the particular store. This is the target variable to be predicted.          |

# %% [markdown]
# ## Loading Data

# %%
filename = "sales_predictions.csv"
df = pd.read_csv(filename)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat             0.02
# 1           DRC01         5.92          Regular             0.02
# 2           FDN15        17.50          Low Fat             0.02
# 3           FDX07        19.20          Regular             0.00
# 4           NCD19         8.93          Low Fat             0.00
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy    249.81            OUT049
# 1            Soft Drinks     48.27            OUT018
# 2                   Meat    141.62            OUT049
# 3  Fruits and Vegetables    182.09            OUT010
# 4              Household     53.86            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998         NaN               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1           3,735.14
# 1  Supermarket Type2             443.42
# 2  Supermarket Type1           2,097.27
# 3      Grocery Store             732.38
# 4  Supermarket Type1             994.71

# %% [markdown]
# ## Data Cleaning
# Dropping duplicates
#
# Fixing inconsistencies in categorical columns

# %%
#number of rows and columns
df.shape
# Out:
# (8523, 12)

# %%
#Datatype for each variable
df.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object

# %%
#drop duplicates
df.duplicated().sum()
# Out:
# 0

# %%
catcols = ["Item_Fat_Content", "Item_Type", "Outlet_Size", "Outlet_Location_Type", "Outlet_Type"]
for col in catcols:
    print(df[col].value_counts())
# Out:
# Low Fat    5089
# Regular    2889
# LF          316
# reg         117
# low fat     112
# Name: Item_Fat_Content, dtype: int64
# Fruits and Vegetables    1232
# Snack Foods              1200
# Household                 910
# Frozen Foods              856
# Dairy                     682
# Canned                    649
# Baking Goods              648
# Health and Hygiene        520
# Soft Drinks               445
# Meat                      425
# Breads                    251
# Hard Drinks               214
# Others                    169
# Starchy Foods             148
# Breakfast                 110
# Seafood                    64
# Name: Item_Type, dtype: int64
# Medium    2793
# Small     2388
# High       932
# Name: Outlet_Size, dtype: int64
# Tier 3    3350
# Tier 2    2785
# Tier 1    2388
# Name: Outlet_Location_Type, dtype: int64
# Supermarket Type1    5577
# Grocery Store        1083
# Supermarket Type3     935
# Supermarket Type2     928
# Name: Outlet_Type, dtype: int64

# %%
# Only categorical column that needs fixing is Item_Fat_Content
df["Item_Fat_Content"].value_counts()
# Out:
# Low Fat    5089
# Regular    2889
# LF          316
# reg         117
# low fat     112
# Name: Item_Fat_Content, dtype: int64

# %%
#Fixing Item Fat Content to Low Fat and Regular Values
replacements = {"LF": "Low Fat",
                "low fat": "Low Fat",
                "reg": "Regular"}
df["Item_Fat_Content"] = df["Item_Fat_Content"].replace(replacements)
df["Item_Fat_Content"].value_counts()
# Out:
# Low Fat    5517
# Regular    3006
# Name: Item_Fat_Content, dtype: int64

# %%
#Obtaining the summary statistics of all numerical columns
df.describe().loc[["min", "max", "mean"]]
# Out:
#       Item_Weight  Item_Visibility  Item_MRP  Outlet_Establishment_Year  \
# min          4.55             0.00     31.29                   1,985.00
# max         21.35             0.33    266.89                   2,009.00
# mean        12.86             0.07    140.99                   1,997.83
#
#       Item_Outlet_Sales
# min               33.29
# max           13,086.96
# mean           2,181.29

# %% [markdown]
# ## Pre-Processing for ML
#
# An aside regarding what might be considered ordinal columns (Outlet_Establishment_Year, Outlet_Size, Outlet_Location_Type):
#
# * I am choosing to utilize Outlet_Establishment_Year as a nominal column at the moment, changing the int datatypes to string datatypes. I feel this better reflects the years as categories rather than numbers for the model to utilize.
#
# * After talking with Yvon Bilodeau, I was informed that Outlet_Location_Type and Outlet_Size did not seem to have a correlation with Item_Outlet_Sales. This will further be expanded upon in a "Food_Sales_Analysis" update at some point in the future to corrobrate this.

# %%
print(df["Outlet_Establishment_Year"].value_counts())
print(df["Outlet_Establishment_Year"].isna().sum())
# Out:
# 1985    1463
# 1987     932
# 1999     930
# 1997     930
# 2004     930
# 2002     929
# 2009     928
# 2007     926
# 1998     555
# Name: Outlet_Establishment_Year, dtype: int64
# 0

# %%
year_replacement_dict = {}
for i in range (1985, 2010):
  year_replacement_dict[i] = str(i)
year_replacement_dict
df["Outlet_Establishment_Year"].replace(year_replacement_dict, inplace = True)

# %%
print(df["Outlet_Size"].value_counts())
print(df["Outlet_Size"].isna().sum())
# Out:
# Medium    2793
# Small     2388
# High       932
# Name: Outlet_Size, dtype: int64
# 2410

# %%
df["Outlet_Size"].fillna("Missing", inplace=True)
df["Outlet_Size"].value_counts()
# Out:
# Medium     2793
# Missing    2410
# Small      2388
# High        932
# Name: Outlet_Size, dtype: int64

# %% [markdown]
# ### Feature and Target Identification

# %%
#Assign the "Item_Outlet_Sales" column as your target and the rest of the relevant 
#variables as your features matrix.
y = df["Item_Outlet_Sales"]
X = df.drop(columns = "Item_Outlet_Sales")

# %%
#Perform a train test split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %% [markdown]
# ### Preprocessing objects

# %%
## make categorical selector and verify it works 
cat_sel = make_column_selector(dtype_include='object')
cat_sel(X_train)
# Out:
# ['Item_Identifier',
#  'Item_Fat_Content',
#  'Item_Type',
#  'Outlet_Identifier',
#  'Outlet_Establishment_Year',
#  'Outlet_Size',
#  'Outlet_Location_Type',
#  'Outlet_Type']

# %%
## make numeric selector and verify it works 
num_sel = make_column_selector(dtype_include='number')
num_sel(X_train)
# Out:
# ['Item_Weight', 'Item_Visibility', 'Item_MRP']

# %%
for col in cat_sel(X):
    print(f"For {col}:\n{X[col].unique()}\n")
# Out:
# For Item_Identifier:
# ['FDA15' 'DRC01' 'FDN15' ... 'NCF55' 'NCW30' 'NCW05']
#
# For Item_Fat_Content:
# ['Low Fat' 'Regular']
#
# For Item_Type:
# ['Dairy' 'Soft Drinks' 'Meat' 'Fruits and Vegetables' 'Household'
#  'Baking Goods' 'Snack Foods' 'Frozen Foods' 'Breakfast'
#  'Health and Hygiene' 'Hard Drinks' 'Canned' 'Breads' 'Starchy Foods'
#  'Others' 'Seafood']
#
# For Outlet_Identifier:
# ['OUT049' 'OUT018' 'OUT010' 'OUT013' 'OUT027' 'OUT045' 'OUT017' 'OUT046'
#  'OUT035' 'OUT019']
#
# For Outlet_Establishment_Year:
# ['1999' '2009' '1998' '1987' '1985' '2002' '2007' '1997' '2004']
#
# For Outlet_Size:
# ['Medium' 'Missing' 'High' 'Small']
#
# For Outlet_Location_Type:
# ['Tier 1' 'Tier 3' 'Tier 2']
#
# For Outlet_Type:
# ['Supermarket Type1' 'Supermarket Type2' 'Grocery Store'
#  'Supermarket Type3']

# %%
## make pipelines for categorical vs numeric data

cat_pipe = make_pipeline(SimpleImputer(strategy='constant', fill_value='MISSING'),
                         OneHotEncoder(drop = "first", handle_unknown='ignore', sparse=False))
num_pipe = make_pipeline(SimpleImputer(strategy='mean'))

# %%
## make the preprocessing column transformer
preprocessor = make_column_transformer((num_pipe, num_sel),
                                       (cat_pipe,cat_sel),                                      
                                       verbose_feature_names_out=False)

# %%
preprocessor.fit(X_train)

X_train_processed = preprocessor.transform(X_train)
X_test_processed = preprocessor.transform(X_test)
# Out:
# /Users/joseph/opt/anaconda3/envs/dojo-env/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:188: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %%
## fit column transformer and run get_feature_names_out
feature_names = preprocessor.get_feature_names_out()
feature_names
# Out:
# array(['Item_Weight', 'Item_Visibility', 'Item_MRP', ...,
#        'Outlet_Type_Supermarket Type1', 'Outlet_Type_Supermarket Type2',
#        'Outlet_Type_Supermarket Type3'], dtype=object)

# %%
X_train_df = pd.DataFrame(preprocessor.transform(X_train), columns = feature_names, index = X_train.index)
X_train_df.head(3)
# Out:
#       Item_Weight  Item_Visibility  Item_MRP  Item_Identifier_DRA24  \
# 4776        16.35             0.03    256.46                   0.00
# 7510        15.25             0.00    179.77                   0.00
# 5828        12.35             0.16    157.29                   0.00
#
#       Item_Identifier_DRA59  Item_Identifier_DRB01  Item_Identifier_DRB13  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_DRB24  Item_Identifier_DRB25  Item_Identifier_DRB48  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_DRC01  Item_Identifier_DRC12  Item_Identifier_DRC13  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_DRC25  Item_Identifier_DRC27  Item_Identifier_DRC36  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_DRC49  Item_Identifier_DRD01  Item_Identifier_DRD12  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_DRD13  Item_Identifier_DRD15  Item_Identifier_DRD24  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_DRD25  Item_Identifier_DRD27  Item_Identifier_DRD37  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_DRD49  Item_Identifier_DRD60  Item_Identifier_DRE01  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_DRE03  Item_Identifier_DRE12  Item_Identifier_DRE13  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_DRE15  Item_Identifier_DRE25  Item_Identifier_DRE27  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_DRE37  Item_Identifier_DRE48  Item_Identifier_DRE49  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_DRE60  Item_Identifier_DRF01  Item_Identifier_DRF03  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_DRF13  Item_Identifier_DRF15  Item_Identifier_DRF23  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_DRF25  Item_Identifier_DRF27  Item_Identifier_DRF36  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_DRF37  Item_Identifier_DRF48  Item_Identifier_DRF49  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_DRF51  Item_Identifier_DRF60  Item_Identifier_DRG01  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_DRG03  Item_Identifier_DRG11  Item_Identifier_DRG13  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_DRG15  Item_Identifier_DRG23  Item_Identifier_DRG25  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_DRG27  Item_Identifier_DRG36  Item_Identifier_DRG37  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_DRG39  Item_Identifier_DRG48  Item_Identifier_DRG49  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_DRG51  Item_Identifier_DRH01  Item_Identifier_DRH03  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_DRH11  Item_Identifier_DRH13  Item_Identifier_DRH15  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_DRH23  Item_Identifier_DRH25  Item_Identifier_DRH36  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_DRH37  Item_Identifier_DRH39  Item_Identifier_DRH49  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_DRH51  Item_Identifier_DRH59  Item_Identifier_DRI01  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_DRI03  Item_Identifier_DRI11  Item_Identifier_DRI13  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_DRI23  Item_Identifier_DRI25  Item_Identifier_DRI37  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_DRI39  Item_Identifier_DRI47  Item_Identifier_DRI49  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_DRI51  Item_Identifier_DRI59  Item_Identifier_DRJ01  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_DRJ11  Item_Identifier_DRJ13  Item_Identifier_DRJ23  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_DRJ24  Item_Identifier_DRJ25  Item_Identifier_DRJ35  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_DRJ37  Item_Identifier_DRJ39  Item_Identifier_DRJ47  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_DRJ49  Item_Identifier_DRJ51  Item_Identifier_DRJ59  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_DRK01  Item_Identifier_DRK11  Item_Identifier_DRK12  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_DRK13  Item_Identifier_DRK23  Item_Identifier_DRK35  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_DRK37  Item_Identifier_DRK39  Item_Identifier_DRK47  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_DRK49  Item_Identifier_DRK59  Item_Identifier_DRL01  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_DRL11  Item_Identifier_DRL23  Item_Identifier_DRL35  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_DRL37  Item_Identifier_DRL47  Item_Identifier_DRL49  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_DRL59  Item_Identifier_DRL60  Item_Identifier_DRM11  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_DRM23  Item_Identifier_DRM35  Item_Identifier_DRM37  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_DRM47  Item_Identifier_DRM48  Item_Identifier_DRM49  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_DRM59  Item_Identifier_DRN11  Item_Identifier_DRN35  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_DRN36  Item_Identifier_DRN37  Item_Identifier_DRN47  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_DRN59  Item_Identifier_DRO35  Item_Identifier_DRO47  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_DRO59  Item_Identifier_DRP35  Item_Identifier_DRP47  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_DRQ35  Item_Identifier_DRY23  Item_Identifier_DRZ11  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_DRZ24  Item_Identifier_FDA01  Item_Identifier_FDA02  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDA03  Item_Identifier_FDA04  Item_Identifier_FDA07  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDA08  Item_Identifier_FDA09  Item_Identifier_FDA10  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDA11  Item_Identifier_FDA13  Item_Identifier_FDA14  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDA15  Item_Identifier_FDA16  Item_Identifier_FDA19  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDA20  Item_Identifier_FDA21  Item_Identifier_FDA22  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDA23  Item_Identifier_FDA25  Item_Identifier_FDA26  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDA27  Item_Identifier_FDA28  Item_Identifier_FDA31  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDA32  Item_Identifier_FDA33  Item_Identifier_FDA34  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDA35  Item_Identifier_FDA36  Item_Identifier_FDA37  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDA38  Item_Identifier_FDA39  Item_Identifier_FDA40  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDA43  Item_Identifier_FDA44  Item_Identifier_FDA45  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDA46  Item_Identifier_FDA47  Item_Identifier_FDA48  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDA49  Item_Identifier_FDA50  Item_Identifier_FDA51  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDA52  Item_Identifier_FDA55  Item_Identifier_FDA56  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDA57  Item_Identifier_FDA58  Item_Identifier_FDB02  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDB03  Item_Identifier_FDB04  Item_Identifier_FDB05  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDB08  Item_Identifier_FDB09  Item_Identifier_FDB10  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDB11  Item_Identifier_FDB12  Item_Identifier_FDB14  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDB15  Item_Identifier_FDB16  Item_Identifier_FDB17  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDB20  Item_Identifier_FDB21  Item_Identifier_FDB22  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDB23  Item_Identifier_FDB26  Item_Identifier_FDB27  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDB28  Item_Identifier_FDB29  Item_Identifier_FDB32  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDB33  Item_Identifier_FDB34  Item_Identifier_FDB35  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDB36  Item_Identifier_FDB37  Item_Identifier_FDB38  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDB39  Item_Identifier_FDB40  Item_Identifier_FDB41  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDB44  Item_Identifier_FDB45  Item_Identifier_FDB46  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDB47  Item_Identifier_FDB49  Item_Identifier_FDB50  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDB51  Item_Identifier_FDB52  Item_Identifier_FDB53  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDB56  Item_Identifier_FDB57  Item_Identifier_FDB58  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDB59  Item_Identifier_FDB60  Item_Identifier_FDC02  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDC03  Item_Identifier_FDC04  Item_Identifier_FDC05  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDC08  Item_Identifier_FDC09  Item_Identifier_FDC10  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDC11  Item_Identifier_FDC14  Item_Identifier_FDC15  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDC16  Item_Identifier_FDC17  Item_Identifier_FDC20  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDC21  Item_Identifier_FDC22  Item_Identifier_FDC26  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDC29  Item_Identifier_FDC32  Item_Identifier_FDC33  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDC34  Item_Identifier_FDC35  Item_Identifier_FDC37  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDC38  Item_Identifier_FDC39  Item_Identifier_FDC40  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDC41  Item_Identifier_FDC44  Item_Identifier_FDC45  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDC46  Item_Identifier_FDC47  Item_Identifier_FDC48  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDC50  Item_Identifier_FDC51  Item_Identifier_FDC52  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDC53  Item_Identifier_FDC56  Item_Identifier_FDC57  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDC58  Item_Identifier_FDC59  Item_Identifier_FDC60  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDD02  Item_Identifier_FDD03  Item_Identifier_FDD04  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDD05  Item_Identifier_FDD08  Item_Identifier_FDD09  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDD10  Item_Identifier_FDD11  Item_Identifier_FDD14  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDD16  Item_Identifier_FDD17  Item_Identifier_FDD20  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDD21  Item_Identifier_FDD22  Item_Identifier_FDD23  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDD26  Item_Identifier_FDD28  Item_Identifier_FDD29  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDD32  Item_Identifier_FDD33  Item_Identifier_FDD34  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDD35  Item_Identifier_FDD36  Item_Identifier_FDD38  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDD39  Item_Identifier_FDD40  Item_Identifier_FDD41  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDD44  Item_Identifier_FDD45  Item_Identifier_FDD46  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDD47  Item_Identifier_FDD48  Item_Identifier_FDD50  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDD51  Item_Identifier_FDD52  Item_Identifier_FDD53  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDD56  Item_Identifier_FDD57  Item_Identifier_FDD58  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDD59  Item_Identifier_FDE02  Item_Identifier_FDE04  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDE05  Item_Identifier_FDE08  Item_Identifier_FDE09  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDE10  Item_Identifier_FDE11  Item_Identifier_FDE14  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDE16  Item_Identifier_FDE17  Item_Identifier_FDE20  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDE21  Item_Identifier_FDE22  Item_Identifier_FDE23  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDE24  Item_Identifier_FDE26  Item_Identifier_FDE28  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDE29  Item_Identifier_FDE32  Item_Identifier_FDE33  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDE34  Item_Identifier_FDE35  Item_Identifier_FDE36  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDE38  Item_Identifier_FDE39  Item_Identifier_FDE40  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDE41  Item_Identifier_FDE44  Item_Identifier_FDE45  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDE46  Item_Identifier_FDE47  Item_Identifier_FDE50  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDE51  Item_Identifier_FDE52  Item_Identifier_FDE53  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDE56  Item_Identifier_FDE57  Item_Identifier_FDE58  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDE59  Item_Identifier_FDF02  Item_Identifier_FDF04  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDF05  Item_Identifier_FDF08  Item_Identifier_FDF09  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDF10  Item_Identifier_FDF11  Item_Identifier_FDF12  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDF14  Item_Identifier_FDF16  Item_Identifier_FDF17  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDF20  Item_Identifier_FDF21  Item_Identifier_FDF22  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDF24  Item_Identifier_FDF26  Item_Identifier_FDF28  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDF29  Item_Identifier_FDF32  Item_Identifier_FDF33  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDF34  Item_Identifier_FDF35  Item_Identifier_FDF38  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDF39  Item_Identifier_FDF40  Item_Identifier_FDF41  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDF44  Item_Identifier_FDF45  Item_Identifier_FDF46  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDF47  Item_Identifier_FDF50  Item_Identifier_FDF52  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDF53  Item_Identifier_FDF56  Item_Identifier_FDF57  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDF58  Item_Identifier_FDF59  Item_Identifier_FDG02  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDG04  Item_Identifier_FDG05  Item_Identifier_FDG08  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDG09  Item_Identifier_FDG10  Item_Identifier_FDG12  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDG14  Item_Identifier_FDG16  Item_Identifier_FDG17  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDG20  Item_Identifier_FDG21  Item_Identifier_FDG22  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDG24  Item_Identifier_FDG26  Item_Identifier_FDG28  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDG29  Item_Identifier_FDG31  Item_Identifier_FDG32  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDG33  Item_Identifier_FDG34  Item_Identifier_FDG35  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDG38  Item_Identifier_FDG40  Item_Identifier_FDG41  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDG44  Item_Identifier_FDG45  Item_Identifier_FDG46  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDG47  Item_Identifier_FDG50  Item_Identifier_FDG52  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDG53  Item_Identifier_FDG56  Item_Identifier_FDG57  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDG58  Item_Identifier_FDG59  Item_Identifier_FDG60  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDH02  Item_Identifier_FDH04  Item_Identifier_FDH05  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDH08  Item_Identifier_FDH09  Item_Identifier_FDH10  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDH12  Item_Identifier_FDH14  Item_Identifier_FDH16  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDH17  Item_Identifier_FDH19  Item_Identifier_FDH20  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDH21  Item_Identifier_FDH22  Item_Identifier_FDH24  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDH26  Item_Identifier_FDH27  Item_Identifier_FDH28  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDH31  Item_Identifier_FDH32  Item_Identifier_FDH33  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDH34  Item_Identifier_FDH35  Item_Identifier_FDH38  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDH40  Item_Identifier_FDH41  Item_Identifier_FDH44  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDH45  Item_Identifier_FDH46  Item_Identifier_FDH47  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDH48  Item_Identifier_FDH50  Item_Identifier_FDH52  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDH53  Item_Identifier_FDH56  Item_Identifier_FDH57  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDH58  Item_Identifier_FDH60  Item_Identifier_FDI02  \
# ...
#
#       Item_Identifier_NCP55  Item_Identifier_NCQ02  Item_Identifier_NCQ05  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_NCQ06  Item_Identifier_NCQ17  Item_Identifier_NCQ18  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_NCQ29  Item_Identifier_NCQ30  Item_Identifier_NCQ38  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_NCQ41  Item_Identifier_NCQ42  Item_Identifier_NCQ43  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_NCQ50  Item_Identifier_NCQ53  Item_Identifier_NCQ54  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_NCR05  Item_Identifier_NCR06  Item_Identifier_NCR17  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_NCR18  Item_Identifier_NCR29  Item_Identifier_NCR30  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_NCR38  Item_Identifier_NCR41  Item_Identifier_NCR42  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_NCR50  Item_Identifier_NCR53  Item_Identifier_NCR54  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_NCS05  Item_Identifier_NCS06  Item_Identifier_NCS17  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_NCS18  Item_Identifier_NCS29  Item_Identifier_NCS30  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_NCS38  Item_Identifier_NCS41  Item_Identifier_NCS42  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_NCS53  Item_Identifier_NCS54  Item_Identifier_NCT05  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_NCT06  Item_Identifier_NCT17  Item_Identifier_NCT18  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_NCT29  Item_Identifier_NCT30  Item_Identifier_NCT41  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_NCT42  Item_Identifier_NCT53  Item_Identifier_NCT54  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_NCU05  Item_Identifier_NCU06  Item_Identifier_NCU17  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_NCU18  Item_Identifier_NCU29  Item_Identifier_NCU30  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_NCU41  Item_Identifier_NCU42  Item_Identifier_NCU53  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_NCU54  Item_Identifier_NCV05  Item_Identifier_NCV06  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_NCV17  Item_Identifier_NCV18  Item_Identifier_NCV29  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_NCV30  Item_Identifier_NCV41  Item_Identifier_NCV42  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_NCV53  Item_Identifier_NCV54  Item_Identifier_NCW05  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_NCW06  Item_Identifier_NCW17  Item_Identifier_NCW18  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_NCW29  Item_Identifier_NCW30  Item_Identifier_NCW41  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_NCW42  Item_Identifier_NCW53  Item_Identifier_NCW54  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_NCX05  Item_Identifier_NCX06  Item_Identifier_NCX17  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_NCX18  Item_Identifier_NCX29  Item_Identifier_NCX30  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_NCX41  Item_Identifier_NCX42  Item_Identifier_NCX53  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_NCX54  Item_Identifier_NCY05  Item_Identifier_NCY06  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_NCY17  Item_Identifier_NCY18  Item_Identifier_NCY29  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_NCY30  Item_Identifier_NCY41  Item_Identifier_NCY42  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_NCY53  Item_Identifier_NCY54  Item_Identifier_NCZ05  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_NCZ06  Item_Identifier_NCZ17  Item_Identifier_NCZ18  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_NCZ29  Item_Identifier_NCZ30  Item_Identifier_NCZ41  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Identifier_NCZ42  Item_Identifier_NCZ53  Item_Identifier_NCZ54  \
# 4776                   0.00                   0.00                   0.00
# 7510                   0.00                   0.00                   0.00
# 5828                   0.00                   0.00                   0.00
#
#       Item_Fat_Content_Regular  Item_Type_Breads  Item_Type_Breakfast  \
# 4776                      0.00              0.00                 0.00
# 7510                      1.00              0.00                 0.00
# 5828                      1.00              0.00                 0.00
#
#       Item_Type_Canned  Item_Type_Dairy  Item_Type_Frozen Foods  \
# 4776              0.00             0.00                    0.00
# 7510              0.00             0.00                    0.00
# 5828              0.00             0.00                    0.00
#
#       Item_Type_Fruits and Vegetables  Item_Type_Hard Drinks  \
# 4776                             0.00                   0.00
# 7510                             0.00                   0.00
# 5828                             0.00                   0.00
#
#       Item_Type_Health and Hygiene  Item_Type_Household  Item_Type_Meat  \
# 4776                          0.00                 1.00            0.00
# 7510                          0.00                 0.00            0.00
# 5828                          0.00                 0.00            1.00
#
#       Item_Type_Others  Item_Type_Seafood  Item_Type_Snack Foods  \
# 4776              0.00               0.00                   0.00
# 7510              0.00               0.00                   1.00
# 5828              0.00               0.00                   0.00
#
#       Item_Type_Soft Drinks  Item_Type_Starchy Foods  \
# 4776                   0.00                     0.00
# 7510                   0.00                     0.00
# 5828                   0.00                     0.00
#
#       Outlet_Identifier_OUT013  Outlet_Identifier_OUT017  \
# 4776                      0.00                      0.00
# 7510                      0.00                      0.00
# 5828                      0.00                      0.00
#
#       Outlet_Identifier_OUT018  Outlet_Identifier_OUT019  \
# 4776                      1.00                      0.00
# 7510                      1.00                      0.00
# 5828                      0.00                      0.00
#
#       Outlet_Identifier_OUT027  Outlet_Identifier_OUT035  \
# 4776                      0.00                      0.00
# 7510                      0.00                      0.00
# 5828                      0.00                      0.00
#
#       Outlet_Identifier_OUT045  Outlet_Identifier_OUT046  \
# 4776                      0.00                      0.00
# 7510                      0.00                      0.00
# 5828                      0.00                      0.00
#
#       Outlet_Identifier_OUT049  Outlet_Establishment_Year_1987  \
# 4776                      0.00                            0.00
# 7510                      0.00                            0.00
# 5828                      1.00                            0.00
#
#       Outlet_Establishment_Year_1997  Outlet_Establishment_Year_1998  \
# 4776                            0.00                            0.00
# 7510                            0.00                            0.00
# 5828                            0.00                            0.00
#
#       Outlet_Establishment_Year_1999  Outlet_Establishment_Year_2002  \
# 4776                            0.00                            0.00
# 7510                            0.00                            0.00
# 5828                            1.00                            0.00
#
#       Outlet_Establishment_Year_2004  Outlet_Establishment_Year_2007  \
# 4776                            0.00                            0.00
# 7510                            0.00                            0.00
# 5828                            0.00                            0.00
#
#       Outlet_Establishment_Year_2009  Outlet_Size_Medium  Outlet_Size_Missing  \
# 4776                            1.00                1.00                 0.00
# 7510                            1.00                1.00                 0.00
# 5828                            0.00                1.00                 0.00
#
#       Outlet_Size_Small  Outlet_Location_Type_Tier 2  \
# 4776               0.00                         0.00
# 7510               0.00                         0.00
# 5828               0.00                         0.00
#
#       Outlet_Location_Type_Tier 3  Outlet_Type_Supermarket Type1  \
# 4776                         1.00                           0.00
# 7510                         1.00                           0.00
# 5828                         0.00                           1.00
#
#       Outlet_Type_Supermarket Type2  Outlet_Type_Supermarket Type3
# 4776                           1.00                           0.00
# 7510                           1.00                           0.00
# 5828                           0.00                           0.00

# %%
X_test_df = pd.DataFrame(preprocessor.transform(X_test),
                           columns = feature_names, index = X_test.index)
X_test_df.head(3)
# Out:
# /Users/joseph/opt/anaconda3/envs/dojo-env/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:188: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
#       Item_Weight  Item_Visibility  Item_MRP  Item_Identifier_DRA24  \
# 7503        14.30             0.03     79.43                   0.00
# 2957         7.93             0.07     42.71                   0.00
# 7031        14.50             0.04     42.05                   0.00
#
#       Item_Identifier_DRA59  Item_Identifier_DRB01  Item_Identifier_DRB13  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_DRB24  Item_Identifier_DRB25  Item_Identifier_DRB48  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_DRC01  Item_Identifier_DRC12  Item_Identifier_DRC13  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_DRC25  Item_Identifier_DRC27  Item_Identifier_DRC36  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_DRC49  Item_Identifier_DRD01  Item_Identifier_DRD12  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_DRD13  Item_Identifier_DRD15  Item_Identifier_DRD24  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_DRD25  Item_Identifier_DRD27  Item_Identifier_DRD37  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_DRD49  Item_Identifier_DRD60  Item_Identifier_DRE01  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_DRE03  Item_Identifier_DRE12  Item_Identifier_DRE13  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_DRE15  Item_Identifier_DRE25  Item_Identifier_DRE27  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_DRE37  Item_Identifier_DRE48  Item_Identifier_DRE49  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_DRE60  Item_Identifier_DRF01  Item_Identifier_DRF03  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_DRF13  Item_Identifier_DRF15  Item_Identifier_DRF23  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_DRF25  Item_Identifier_DRF27  Item_Identifier_DRF36  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_DRF37  Item_Identifier_DRF48  Item_Identifier_DRF49  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_DRF51  Item_Identifier_DRF60  Item_Identifier_DRG01  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_DRG03  Item_Identifier_DRG11  Item_Identifier_DRG13  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_DRG15  Item_Identifier_DRG23  Item_Identifier_DRG25  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_DRG27  Item_Identifier_DRG36  Item_Identifier_DRG37  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_DRG39  Item_Identifier_DRG48  Item_Identifier_DRG49  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_DRG51  Item_Identifier_DRH01  Item_Identifier_DRH03  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_DRH11  Item_Identifier_DRH13  Item_Identifier_DRH15  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_DRH23  Item_Identifier_DRH25  Item_Identifier_DRH36  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_DRH37  Item_Identifier_DRH39  Item_Identifier_DRH49  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_DRH51  Item_Identifier_DRH59  Item_Identifier_DRI01  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_DRI03  Item_Identifier_DRI11  Item_Identifier_DRI13  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_DRI23  Item_Identifier_DRI25  Item_Identifier_DRI37  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_DRI39  Item_Identifier_DRI47  Item_Identifier_DRI49  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_DRI51  Item_Identifier_DRI59  Item_Identifier_DRJ01  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_DRJ11  Item_Identifier_DRJ13  Item_Identifier_DRJ23  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_DRJ24  Item_Identifier_DRJ25  Item_Identifier_DRJ35  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_DRJ37  Item_Identifier_DRJ39  Item_Identifier_DRJ47  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_DRJ49  Item_Identifier_DRJ51  Item_Identifier_DRJ59  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_DRK01  Item_Identifier_DRK11  Item_Identifier_DRK12  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_DRK13  Item_Identifier_DRK23  Item_Identifier_DRK35  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_DRK37  Item_Identifier_DRK39  Item_Identifier_DRK47  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_DRK49  Item_Identifier_DRK59  Item_Identifier_DRL01  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_DRL11  Item_Identifier_DRL23  Item_Identifier_DRL35  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_DRL37  Item_Identifier_DRL47  Item_Identifier_DRL49  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_DRL59  Item_Identifier_DRL60  Item_Identifier_DRM11  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_DRM23  Item_Identifier_DRM35  Item_Identifier_DRM37  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_DRM47  Item_Identifier_DRM48  Item_Identifier_DRM49  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_DRM59  Item_Identifier_DRN11  Item_Identifier_DRN35  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_DRN36  Item_Identifier_DRN37  Item_Identifier_DRN47  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_DRN59  Item_Identifier_DRO35  Item_Identifier_DRO47  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_DRO59  Item_Identifier_DRP35  Item_Identifier_DRP47  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_DRQ35  Item_Identifier_DRY23  Item_Identifier_DRZ11  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_DRZ24  Item_Identifier_FDA01  Item_Identifier_FDA02  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDA03  Item_Identifier_FDA04  Item_Identifier_FDA07  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDA08  Item_Identifier_FDA09  Item_Identifier_FDA10  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDA11  Item_Identifier_FDA13  Item_Identifier_FDA14  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDA15  Item_Identifier_FDA16  Item_Identifier_FDA19  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDA20  Item_Identifier_FDA21  Item_Identifier_FDA22  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDA23  Item_Identifier_FDA25  Item_Identifier_FDA26  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDA27  Item_Identifier_FDA28  Item_Identifier_FDA31  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDA32  Item_Identifier_FDA33  Item_Identifier_FDA34  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDA35  Item_Identifier_FDA36  Item_Identifier_FDA37  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDA38  Item_Identifier_FDA39  Item_Identifier_FDA40  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDA43  Item_Identifier_FDA44  Item_Identifier_FDA45  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDA46  Item_Identifier_FDA47  Item_Identifier_FDA48  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDA49  Item_Identifier_FDA50  Item_Identifier_FDA51  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDA52  Item_Identifier_FDA55  Item_Identifier_FDA56  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDA57  Item_Identifier_FDA58  Item_Identifier_FDB02  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDB03  Item_Identifier_FDB04  Item_Identifier_FDB05  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDB08  Item_Identifier_FDB09  Item_Identifier_FDB10  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDB11  Item_Identifier_FDB12  Item_Identifier_FDB14  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDB15  Item_Identifier_FDB16  Item_Identifier_FDB17  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDB20  Item_Identifier_FDB21  Item_Identifier_FDB22  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDB23  Item_Identifier_FDB26  Item_Identifier_FDB27  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDB28  Item_Identifier_FDB29  Item_Identifier_FDB32  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDB33  Item_Identifier_FDB34  Item_Identifier_FDB35  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDB36  Item_Identifier_FDB37  Item_Identifier_FDB38  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDB39  Item_Identifier_FDB40  Item_Identifier_FDB41  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDB44  Item_Identifier_FDB45  Item_Identifier_FDB46  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDB47  Item_Identifier_FDB49  Item_Identifier_FDB50  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDB51  Item_Identifier_FDB52  Item_Identifier_FDB53  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDB56  Item_Identifier_FDB57  Item_Identifier_FDB58  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDB59  Item_Identifier_FDB60  Item_Identifier_FDC02  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDC03  Item_Identifier_FDC04  Item_Identifier_FDC05  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDC08  Item_Identifier_FDC09  Item_Identifier_FDC10  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDC11  Item_Identifier_FDC14  Item_Identifier_FDC15  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   1.00                   0.00
#
#       Item_Identifier_FDC16  Item_Identifier_FDC17  Item_Identifier_FDC20  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDC21  Item_Identifier_FDC22  Item_Identifier_FDC26  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDC29  Item_Identifier_FDC32  Item_Identifier_FDC33  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDC34  Item_Identifier_FDC35  Item_Identifier_FDC37  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDC38  Item_Identifier_FDC39  Item_Identifier_FDC40  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDC41  Item_Identifier_FDC44  Item_Identifier_FDC45  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDC46  Item_Identifier_FDC47  Item_Identifier_FDC48  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDC50  Item_Identifier_FDC51  Item_Identifier_FDC52  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDC53  Item_Identifier_FDC56  Item_Identifier_FDC57  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDC58  Item_Identifier_FDC59  Item_Identifier_FDC60  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDD02  Item_Identifier_FDD03  Item_Identifier_FDD04  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDD05  Item_Identifier_FDD08  Item_Identifier_FDD09  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDD10  Item_Identifier_FDD11  Item_Identifier_FDD14  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDD16  Item_Identifier_FDD17  Item_Identifier_FDD20  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDD21  Item_Identifier_FDD22  Item_Identifier_FDD23  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDD26  Item_Identifier_FDD28  Item_Identifier_FDD29  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDD32  Item_Identifier_FDD33  Item_Identifier_FDD34  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDD35  Item_Identifier_FDD36  Item_Identifier_FDD38  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDD39  Item_Identifier_FDD40  Item_Identifier_FDD41  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDD44  Item_Identifier_FDD45  Item_Identifier_FDD46  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDD47  Item_Identifier_FDD48  Item_Identifier_FDD50  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDD51  Item_Identifier_FDD52  Item_Identifier_FDD53  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDD56  Item_Identifier_FDD57  Item_Identifier_FDD58  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDD59  Item_Identifier_FDE02  Item_Identifier_FDE04  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDE05  Item_Identifier_FDE08  Item_Identifier_FDE09  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDE10  Item_Identifier_FDE11  Item_Identifier_FDE14  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDE16  Item_Identifier_FDE17  Item_Identifier_FDE20  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDE21  Item_Identifier_FDE22  Item_Identifier_FDE23  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDE24  Item_Identifier_FDE26  Item_Identifier_FDE28  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDE29  Item_Identifier_FDE32  Item_Identifier_FDE33  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDE34  Item_Identifier_FDE35  Item_Identifier_FDE36  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDE38  Item_Identifier_FDE39  Item_Identifier_FDE40  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDE41  Item_Identifier_FDE44  Item_Identifier_FDE45  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDE46  Item_Identifier_FDE47  Item_Identifier_FDE50  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDE51  Item_Identifier_FDE52  Item_Identifier_FDE53  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDE56  Item_Identifier_FDE57  Item_Identifier_FDE58  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDE59  Item_Identifier_FDF02  Item_Identifier_FDF04  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDF05  Item_Identifier_FDF08  Item_Identifier_FDF09  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDF10  Item_Identifier_FDF11  Item_Identifier_FDF12  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDF14  Item_Identifier_FDF16  Item_Identifier_FDF17  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDF20  Item_Identifier_FDF21  Item_Identifier_FDF22  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDF24  Item_Identifier_FDF26  Item_Identifier_FDF28  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDF29  Item_Identifier_FDF32  Item_Identifier_FDF33  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDF34  Item_Identifier_FDF35  Item_Identifier_FDF38  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDF39  Item_Identifier_FDF40  Item_Identifier_FDF41  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDF44  Item_Identifier_FDF45  Item_Identifier_FDF46  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDF47  Item_Identifier_FDF50  Item_Identifier_FDF52  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDF53  Item_Identifier_FDF56  Item_Identifier_FDF57  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDF58  Item_Identifier_FDF59  Item_Identifier_FDG02  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDG04  Item_Identifier_FDG05  Item_Identifier_FDG08  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDG09  Item_Identifier_FDG10  Item_Identifier_FDG12  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDG14  Item_Identifier_FDG16  Item_Identifier_FDG17  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDG20  Item_Identifier_FDG21  Item_Identifier_FDG22  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDG24  Item_Identifier_FDG26  Item_Identifier_FDG28  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDG29  Item_Identifier_FDG31  Item_Identifier_FDG32  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDG33  Item_Identifier_FDG34  Item_Identifier_FDG35  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDG38  Item_Identifier_FDG40  Item_Identifier_FDG41  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDG44  Item_Identifier_FDG45  Item_Identifier_FDG46  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDG47  Item_Identifier_FDG50  Item_Identifier_FDG52  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDG53  Item_Identifier_FDG56  Item_Identifier_FDG57  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDG58  Item_Identifier_FDG59  Item_Identifier_FDG60  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDH02  Item_Identifier_FDH04  Item_Identifier_FDH05  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDH08  Item_Identifier_FDH09  Item_Identifier_FDH10  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDH12  Item_Identifier_FDH14  Item_Identifier_FDH16  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDH17  Item_Identifier_FDH19  Item_Identifier_FDH20  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDH21  Item_Identifier_FDH22  Item_Identifier_FDH24  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDH26  Item_Identifier_FDH27  Item_Identifier_FDH28  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDH31  Item_Identifier_FDH32  Item_Identifier_FDH33  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDH34  Item_Identifier_FDH35  Item_Identifier_FDH38  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDH40  Item_Identifier_FDH41  Item_Identifier_FDH44  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDH45  Item_Identifier_FDH46  Item_Identifier_FDH47  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDH48  Item_Identifier_FDH50  Item_Identifier_FDH52  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_FDH53  Item_Identifier_FDH56  Item_Identifier_FDH57  \
# 7503                   0.00                   0.00                   0.00
# ...
#
#       Item_Identifier_NCP55  Item_Identifier_NCQ02  Item_Identifier_NCQ05  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_NCQ06  Item_Identifier_NCQ17  Item_Identifier_NCQ18  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_NCQ29  Item_Identifier_NCQ30  Item_Identifier_NCQ38  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_NCQ41  Item_Identifier_NCQ42  Item_Identifier_NCQ43  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_NCQ50  Item_Identifier_NCQ53  Item_Identifier_NCQ54  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_NCR05  Item_Identifier_NCR06  Item_Identifier_NCR17  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_NCR18  Item_Identifier_NCR29  Item_Identifier_NCR30  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_NCR38  Item_Identifier_NCR41  Item_Identifier_NCR42  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_NCR50  Item_Identifier_NCR53  Item_Identifier_NCR54  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_NCS05  Item_Identifier_NCS06  Item_Identifier_NCS17  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_NCS18  Item_Identifier_NCS29  Item_Identifier_NCS30  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_NCS38  Item_Identifier_NCS41  Item_Identifier_NCS42  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_NCS53  Item_Identifier_NCS54  Item_Identifier_NCT05  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_NCT06  Item_Identifier_NCT17  Item_Identifier_NCT18  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_NCT29  Item_Identifier_NCT30  Item_Identifier_NCT41  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_NCT42  Item_Identifier_NCT53  Item_Identifier_NCT54  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_NCU05  Item_Identifier_NCU06  Item_Identifier_NCU17  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_NCU18  Item_Identifier_NCU29  Item_Identifier_NCU30  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_NCU41  Item_Identifier_NCU42  Item_Identifier_NCU53  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_NCU54  Item_Identifier_NCV05  Item_Identifier_NCV06  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_NCV17  Item_Identifier_NCV18  Item_Identifier_NCV29  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_NCV30  Item_Identifier_NCV41  Item_Identifier_NCV42  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_NCV53  Item_Identifier_NCV54  Item_Identifier_NCW05  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_NCW06  Item_Identifier_NCW17  Item_Identifier_NCW18  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_NCW29  Item_Identifier_NCW30  Item_Identifier_NCW41  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_NCW42  Item_Identifier_NCW53  Item_Identifier_NCW54  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_NCX05  Item_Identifier_NCX06  Item_Identifier_NCX17  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_NCX18  Item_Identifier_NCX29  Item_Identifier_NCX30  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_NCX41  Item_Identifier_NCX42  Item_Identifier_NCX53  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_NCX54  Item_Identifier_NCY05  Item_Identifier_NCY06  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_NCY17  Item_Identifier_NCY18  Item_Identifier_NCY29  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_NCY30  Item_Identifier_NCY41  Item_Identifier_NCY42  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_NCY53  Item_Identifier_NCY54  Item_Identifier_NCZ05  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_NCZ06  Item_Identifier_NCZ17  Item_Identifier_NCZ18  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_NCZ29  Item_Identifier_NCZ30  Item_Identifier_NCZ41  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Identifier_NCZ42  Item_Identifier_NCZ53  Item_Identifier_NCZ54  \
# 7503                   0.00                   0.00                   0.00
# 2957                   0.00                   0.00                   0.00
# 7031                   0.00                   0.00                   0.00
#
#       Item_Fat_Content_Regular  Item_Type_Breads  Item_Type_Breakfast  \
# 7503                      0.00              0.00                 0.00
# 2957                      0.00              0.00                 0.00
# 7031                      1.00              0.00                 0.00
#
#       Item_Type_Canned  Item_Type_Dairy  Item_Type_Frozen Foods  \
# 7503              0.00             0.00                    1.00
# 2957              0.00             0.00                    0.00
# 7031              1.00             0.00                    0.00
#
#       Item_Type_Fruits and Vegetables  Item_Type_Hard Drinks  \
# 7503                             0.00                   0.00
# 2957                             0.00                   0.00
# 7031                             0.00                   0.00
#
#       Item_Type_Health and Hygiene  Item_Type_Household  Item_Type_Meat  \
# 7503                          0.00                 0.00            0.00
# 2957                          1.00                 0.00            0.00
# 7031                          0.00                 0.00            0.00
#
#       Item_Type_Others  Item_Type_Seafood  Item_Type_Snack Foods  \
# 7503              0.00               0.00                   0.00
# 2957              0.00               0.00                   0.00
# 7031              0.00               0.00                   0.00
#
#       Item_Type_Soft Drinks  Item_Type_Starchy Foods  \
# 7503                   0.00                     0.00
# 2957                   0.00                     0.00
# 7031                   0.00                     0.00
#
#       Outlet_Identifier_OUT013  Outlet_Identifier_OUT017  \
# 7503                      1.00                      0.00
# 2957                      0.00                      0.00
# 7031                      0.00                      0.00
#
#       Outlet_Identifier_OUT018  Outlet_Identifier_OUT019  \
# 7503                      0.00                      0.00
# 2957                      0.00                      0.00
# 7031                      0.00                      0.00
#
#       Outlet_Identifier_OUT027  Outlet_Identifier_OUT035  \
# 7503                      0.00                      0.00
# 2957                      0.00                      0.00
# 7031                      0.00                      0.00
#
#       Outlet_Identifier_OUT045  Outlet_Identifier_OUT046  \
# 7503                      0.00                      0.00
# 2957                      0.00                      1.00
# 7031                      0.00                      0.00
#
#       Outlet_Identifier_OUT049  Outlet_Establishment_Year_1987  \
# 7503                      0.00                            1.00
# 2957                      0.00                            0.00
# 7031                      1.00                            0.00
#
#       Outlet_Establishment_Year_1997  Outlet_Establishment_Year_1998  \
# 7503                            0.00                            0.00
# 2957                            1.00                            0.00
# 7031                            0.00                            0.00
#
#       Outlet_Establishment_Year_1999  Outlet_Establishment_Year_2002  \
# 7503                            0.00                            0.00
# 2957                            0.00                            0.00
# 7031                            1.00                            0.00
#
#       Outlet_Establishment_Year_2004  Outlet_Establishment_Year_2007  \
# 7503                            0.00                            0.00
# 2957                            0.00                            0.00
# 7031                            0.00                            0.00
#
#       Outlet_Establishment_Year_2009  Outlet_Size_Medium  Outlet_Size_Missing  \
# 7503                            0.00                0.00                 0.00
# 2957                            0.00                0.00                 0.00
# 7031                            0.00                1.00                 0.00
#
#       Outlet_Size_Small  Outlet_Location_Type_Tier 2  \
# 7503               0.00                         0.00
# 2957               1.00                         0.00
# 7031               0.00                         0.00
#
#       Outlet_Location_Type_Tier 3  Outlet_Type_Supermarket Type1  \
# 7503                         1.00                           1.00
# 2957                         0.00                           1.00
# 7031                         0.00                           1.00
#
#       Outlet_Type_Supermarket Type2  Outlet_Type_Supermarket Type3
# 7503                           0.00                           0.00
# 2957                           0.00                           0.00
# 7031                           0.00                           0.00

# %%
## confirm the first 3 rows index in y_test matches X_test_df
y_test.head(3)
# Out:
# 7503   1,743.06
# 2957     356.87
# 7031     377.51
# Name: Item_Outlet_Sales, dtype: float64

# %% [markdown]
# ## Regressions
#
# 1. Linear Regression Model
# 2. Regression Tree Model
# 3. Keras Deep Learning Model
#
# For all regresions, evaluate performance based off of r^2 and RMSE.

# %%
def evaluate_regression(model, X_train,y_train, X_test, y_test): 
    """Evaluates a scikit learn regression model using r-squared and RMSE"""
    
    ## Training Data
    y_pred_train = model.predict(X_train)
    r2_train = r2_score(y_train, y_pred_train)
    rmse_train = mean_squared_error(y_train, y_pred_train, 
                                            squared=False)
    
    print(f"Training Data:\tR^2= {r2_train:.2f}\tRMSE= {rmse_train:.2f}")
        
    
    ## Test Data
    y_pred_test = model.predict(X_test)
    r2_test = r2_score(y_test, y_pred_test)
    rmse_test = mean_squared_error(y_test, y_pred_test, 
                                            squared=False)
    
    print(f"Test Data:\tR^2= {r2_test:.2f}\tRMSE= {rmse_test:.2f}")

# %% [markdown]
# ### LINEAR REGRESSION MODEL
#
# Evaluate the performance of your model based on r^2 and RMSE

# %%
#Creating Regressor instance
reg = LinearRegression()

reg.fit(X_train_df, y_train)
evaluate_regression(reg, X_train_df, y_train, X_test_df, y_test)
# Out:
# Training Data:	R^2= 0.67	RMSE= 985.70
# Test Data:	R^2= 0.38	RMSE= 1304.70

# %%
reg.feature_names_in_
# Out:
# array(['Item_Weight', 'Item_Visibility', 'Item_MRP', ...,
#        'Outlet_Type_Supermarket Type1', 'Outlet_Type_Supermarket Type2',
#        'Outlet_Type_Supermarket Type3'], dtype=object)

# %%
## Saving the coefficients
coeffs = pd.Series(reg.coef_, index= reg.feature_names_in_)
coeffs['intercept'] = reg.intercept_
coeffs
# Out:
# Item_Weight                            2.53
# Item_Visibility                     -549.71
# Item_MRP                             -11.16
# Item_Identifier_DRA24                844.76
# Item_Identifier_DRA59              1,517.53
# Item_Identifier_DRB01               -133.55
# Item_Identifier_DRB13              1,510.56
# Item_Identifier_DRB24              1,290.39
# Item_Identifier_DRB25               -358.77
# Item_Identifier_DRB48             -2,632.93
# Item_Identifier_DRC01             -2,061.40
# Item_Identifier_DRC12              1,004.09
# Item_Identifier_DRC13               -704.99
# Item_Identifier_DRC25               -778.66
# Item_Identifier_DRC27                628.89
# Item_Identifier_DRC36                845.03
# Item_Identifier_DRC49                684.20
# Item_Identifier_DRD01             -2,213.61
# Item_Identifier_DRD12               -844.23
# Item_Identifier_DRD13             -1,529.66
# Item_Identifier_DRD15              1,760.82
# Item_Identifier_DRD24                342.29
# Item_Identifier_DRD25                 22.55
# Item_Identifier_DRD27               -971.60
# Item_Identifier_DRD37             -1,741.62
# Item_Identifier_DRD49              3,058.82
# Item_Identifier_DRD60              2,136.06
# Item_Identifier_DRE01              3,433.31
# Item_Identifier_DRE03             -2,814.44
# Item_Identifier_DRE12               -481.77
# Item_Identifier_DRE13             -1,100.76
# Item_Identifier_DRE15             -1,700.64
# Item_Identifier_DRE25             -1,096.90
# Item_Identifier_DRE27             -1,459.72
# Item_Identifier_DRE37              1,388.82
# Item_Identifier_DRE48              2,551.65
# Item_Identifier_DRE49              1,138.31
# Item_Identifier_DRE60              4,018.85
# Item_Identifier_DRF01                 88.63
# Item_Identifier_DRF03             -3,086.46
# Item_Identifier_DRF13              1,298.05
# Item_Identifier_DRF15               -721.78
# Item_Identifier_DRF23              1,113.88
# Item_Identifier_DRF25             -2,039.66
# Item_Identifier_DRF27                306.18
# Item_Identifier_DRF36              3,271.97
# Item_Identifier_DRF37              3,316.30
# Item_Identifier_DRF48                407.74
# Item_Identifier_DRF49               -205.60
# Item_Identifier_DRF51             -2,301.67
# Item_Identifier_DRF60              3,939.15
# Item_Identifier_DRG01             -1,163.10
# Item_Identifier_DRG03                666.82
# Item_Identifier_DRG11             -1,343.52
# Item_Identifier_DRG13              1,206.55
# Item_Identifier_DRG15             -1,850.58
# Item_Identifier_DRG23               -397.47
# Item_Identifier_DRG25              3,280.89
# Item_Identifier_DRG27             -2,260.72
# Item_Identifier_DRG36              1,957.45
# Item_Identifier_DRG37                420.07
# Item_Identifier_DRG39             -2,028.43
# Item_Identifier_DRG48                635.61
# Item_Identifier_DRG49              3,512.01
# Item_Identifier_DRG51                284.96
# Item_Identifier_DRH01              1,348.51
# Item_Identifier_DRH03             -1,475.32
# Item_Identifier_DRH11             -2,593.26
# Item_Identifier_DRH13               -748.46
# Item_Identifier_DRH15             -2,066.67
# Item_Identifier_DRH23             -2,171.34
# Item_Identifier_DRH25             -1,707.47
# Item_Identifier_DRH36             -1,149.45
# Item_Identifier_DRH37                522.53
# Item_Identifier_DRH39             -1,034.18
# Item_Identifier_DRH49             -1,242.35
# Item_Identifier_DRH51             -1,786.62
# Item_Identifier_DRH59               -903.09
# Item_Identifier_DRI01              2,220.30
# Item_Identifier_DRI03              1,017.09
# Item_Identifier_DRI11               -778.52
# Item_Identifier_DRI13              1,350.64
# Item_Identifier_DRI23                962.05
# Item_Identifier_DRI25             -2,144.94
# Item_Identifier_DRI37             -1,750.89
# Item_Identifier_DRI39             -2,054.27
# Item_Identifier_DRI47                400.11
# Item_Identifier_DRI49               -945.73
# Item_Identifier_DRI51              1,698.54
# Item_Identifier_DRI59              2,521.47
# Item_Identifier_DRJ01                 30.28
# Item_Identifier_DRJ11              1,530.15
# Item_Identifier_DRJ13              1,136.56
# Item_Identifier_DRJ23              1,247.48
# Item_Identifier_DRJ24              1,294.99
# Item_Identifier_DRJ25             -1,645.16
# Item_Identifier_DRJ35             -2,459.01
# Item_Identifier_DRJ37                857.01
# Item_Identifier_DRJ39              2,269.11
# Item_Identifier_DRJ47              1,683.08
# Item_Identifier_DRJ49                167.49
# Item_Identifier_DRJ51              1,483.30
# Item_Identifier_DRJ59             -2,421.04
# Item_Identifier_DRK01               -815.30
# Item_Identifier_DRK11               -393.49
# Item_Identifier_DRK12             -2,388.08
# Item_Identifier_DRK13              2,630.18
# Item_Identifier_DRK23              3,791.05
# Item_Identifier_DRK35             -2,262.31
# Item_Identifier_DRK37              3,269.90
# Item_Identifier_DRK39             -1,991.39
# Item_Identifier_DRK47              2,026.52
# Item_Identifier_DRK49             -2,202.79
# Item_Identifier_DRK59              1,217.51
# Item_Identifier_DRL01              4,556.05
# Item_Identifier_DRL11              1,103.27
# Item_Identifier_DRL23               -932.11
# Item_Identifier_DRL35             -2,495.66
# Item_Identifier_DRL37             -2,199.99
# Item_Identifier_DRL47             -1,356.53
# Item_Identifier_DRL49               -450.96
# Item_Identifier_DRL59             -1,153.36
# Item_Identifier_DRL60                991.12
# Item_Identifier_DRM11              2,946.82
# Item_Identifier_DRM23                728.30
# Item_Identifier_DRM35              2,634.76
# Item_Identifier_DRM37              2,909.79
# Item_Identifier_DRM47              1,635.80
# Item_Identifier_DRM48             -2,643.89
# Item_Identifier_DRM49             -1,558.59
# Item_Identifier_DRM59                409.19
# Item_Identifier_DRN11                408.44
# Item_Identifier_DRN35             -2,356.79
# Item_Identifier_DRN36               -887.00
# Item_Identifier_DRN37                709.66
# Item_Identifier_DRN47              1,264.87
# Item_Identifier_DRN59             -2,861.60
# Item_Identifier_DRO35                 66.91
# Item_Identifier_DRO47               -696.21
# Item_Identifier_DRO59             -1,449.95
# Item_Identifier_DRP35                -86.41
# Item_Identifier_DRP47              1,741.22
# Item_Identifier_DRQ35                -18.05
# Item_Identifier_DRY23             -2,246.07
# Item_Identifier_DRZ11               -229.09
# Item_Identifier_DRZ24                735.91
# Item_Identifier_FDA01             -2,352.21
# Item_Identifier_FDA02               -711.02
# Item_Identifier_FDA03                 21.16
# Item_Identifier_FDA04              3,255.84
# Item_Identifier_FDA07               -654.88
# Item_Identifier_FDA08                128.72
# Item_Identifier_FDA09               -229.70
# Item_Identifier_FDA10               -747.49
# Item_Identifier_FDA11             -2,166.97
# Item_Identifier_FDA13             -2,831.64
# Item_Identifier_FDA14               -320.76
# Item_Identifier_FDA15              4,364.07
# Item_Identifier_FDA16              2,784.01
# Item_Identifier_FDA19               -350.40
# Item_Identifier_FDA20                992.03
# Item_Identifier_FDA21              2,190.77
# Item_Identifier_FDA22              1,237.41
# Item_Identifier_FDA23               -729.58
# Item_Identifier_FDA25             -1,161.26
# Item_Identifier_FDA26              1,920.86
# Item_Identifier_FDA27              1,952.68
# Item_Identifier_FDA28               -335.49
# Item_Identifier_FDA31                281.36
# Item_Identifier_FDA32                921.60
# Item_Identifier_FDA33                201.54
# Item_Identifier_FDA34              1,621.15
# Item_Identifier_FDA35               -387.65
# Item_Identifier_FDA36                551.67
# Item_Identifier_FDA37                659.55
# Item_Identifier_FDA38              1,767.65
# Item_Identifier_FDA39             -2,206.33
# Item_Identifier_FDA40             -2,152.34
# Item_Identifier_FDA43                778.02
# Item_Identifier_FDA44             -2,392.71
# Item_Identifier_FDA45                221.22
# Item_Identifier_FDA46              1,577.63
# Item_Identifier_FDA47              1,533.79
# Item_Identifier_FDA48              3,384.20
# Item_Identifier_FDA49             -1,458.32
# Item_Identifier_FDA50             -1,561.62
# Item_Identifier_FDA51             -1,019.46
# Item_Identifier_FDA52                766.12
# Item_Identifier_FDA55              2,520.01
# Item_Identifier_FDA56               -623.92
# Item_Identifier_FDA57             -3,201.76
# Item_Identifier_FDA58                862.40
# Item_Identifier_FDB02                928.45
# Item_Identifier_FDB03              2,183.82
# Item_Identifier_FDB04             -1,628.60
# Item_Identifier_FDB05              3,313.40
# Item_Identifier_FDB08               -201.91
# Item_Identifier_FDB09               -834.21
# Item_Identifier_FDB10                916.37
# Item_Identifier_FDB11              2,874.39
# Item_Identifier_FDB12               -182.84
# Item_Identifier_FDB14             -1,159.11
# Item_Identifier_FDB15              2,493.27
# Item_Identifier_FDB16             -1,918.97
# Item_Identifier_FDB17              1,511.35
# Item_Identifier_FDB20             -1,821.59
# Item_Identifier_FDB21              4,453.12
# Item_Identifier_FDB22               -132.86
# Item_Identifier_FDB23              2,008.76
# Item_Identifier_FDB26             -2,878.39
# Item_Identifier_FDB27              1,704.25
# Item_Identifier_FDB28                683.56
# Item_Identifier_FDB29             -1,315.52
# Item_Identifier_FDB32               -803.18
# Item_Identifier_FDB33              1,016.59
# Item_Identifier_FDB34             -1,519.82
# Item_Identifier_FDB35             -1,129.92
# Item_Identifier_FDB36                -26.66
# Item_Identifier_FDB37              3,146.56
# Item_Identifier_FDB38                362.74
# Item_Identifier_FDB39             -2,515.26
# Item_Identifier_FDB40                338.25
# Item_Identifier_FDB41             -1,594.09
# Item_Identifier_FDB44              2,201.67
# Item_Identifier_FDB45             -1,264.38
# Item_Identifier_FDB46              2,005.66
# Item_Identifier_FDB47                641.56
# Item_Identifier_FDB49               -208.74
# Item_Identifier_FDB50             -1,362.98
# Item_Identifier_FDB51             -2,513.33
# Item_Identifier_FDB52              1,665.48
# Item_Identifier_FDB53                783.98
# Item_Identifier_FDB56              2,094.96
# Item_Identifier_FDB57              2,330.28
# Item_Identifier_FDB58                174.53
# Item_Identifier_FDB59                144.02
# Item_Identifier_FDB60              1,725.71
# Item_Identifier_FDC02              4,567.43
# Item_Identifier_FDC03              1,240.10
# Item_Identifier_FDC04              1,190.99
# Item_Identifier_FDC05              1,370.44
# Item_Identifier_FDC08              1,505.83
# Item_Identifier_FDC09             -1,499.86
# Item_Identifier_FDC10             -1,742.71
# Item_Identifier_FDC11             -1,110.40
# Item_Identifier_FDC14             -2,187.01
# Item_Identifier_FDC15                 16.86
# Item_Identifier_FDC16             -1,840.74
# Item_Identifier_FDC17              2,309.38
# Item_Identifier_FDC20             -2,408.31
# Item_Identifier_FDC21             -1,041.27
# Item_Identifier_FDC22              1,170.58
# Item_Identifier_FDC26               -907.37
# Item_Identifier_FDC29               -985.84
# Item_Identifier_FDC32             -1,599.51
# Item_Identifier_FDC33              1,052.84
# Item_Identifier_FDC34                948.48
# Item_Identifier_FDC35              1,017.00
# Item_Identifier_FDC37                292.08
# Item_Identifier_FDC38               -423.65
# Item_Identifier_FDC39              1,952.35
# Item_Identifier_FDC40             -1,830.43
# Item_Identifier_FDC41             -1,349.39
# Item_Identifier_FDC44               -130.46
# Item_Identifier_FDC45               -369.66
# Item_Identifier_FDC46              2,030.26
# Item_Identifier_FDC47              3,197.57
# Item_Identifier_FDC48               -750.59
# Item_Identifier_FDC50               -894.30
# Item_Identifier_FDC51               -544.94
# Item_Identifier_FDC52               -288.45
# Item_Identifier_FDC53             -1,281.28
# Item_Identifier_FDC56                336.45
# Item_Identifier_FDC57                492.03
# Item_Identifier_FDC58             -3,614.24
# Item_Identifier_FDC59             -2,093.39
# Item_Identifier_FDC60                -63.67
# Item_Identifier_FDD02               -316.80
# Item_Identifier_FDD03              1,700.61
# Item_Identifier_FDD04               -476.22
# Item_Identifier_FDD05               -146.00
# Item_Identifier_FDD08             -3,342.17
# Item_Identifier_FDD09              1,391.94
# Item_Identifier_FDD10               -127.81
# Item_Identifier_FDD11              1,708.32
# Item_Identifier_FDD14              1,070.12
# Item_Identifier_FDD16             -1,404.05
# Item_Identifier_FDD17              2,820.55
# Item_Identifier_FDD20                 65.48
# Item_Identifier_FDD21               -173.40
# Item_Identifier_FDD22              1,099.23
# Item_Identifier_FDD23              1,315.66
# Item_Identifier_FDD26              1,366.55
# Item_Identifier_FDD28             -2,482.92
# Item_Identifier_FDD29              3,507.70
# Item_Identifier_FDD32             -1,937.35
# Item_Identifier_FDD33              2,664.22
# Item_Identifier_FDD34                463.97
# Item_Identifier_FDD35               -717.37
# Item_Identifier_FDD36               -521.06
# Item_Identifier_FDD38             -1,017.82
# Item_Identifier_FDD39              2,094.20
# Item_Identifier_FDD40              1,302.39
# Item_Identifier_FDD41               -987.66
# Item_Identifier_FDD44              4,376.66
# Item_Identifier_FDD45             -1,699.00
# Item_Identifier_FDD46               -411.93
# Item_Identifier_FDD47              1,387.29
# Item_Identifier_FDD48                -33.41
# Item_Identifier_FDD50                977.16
# Item_Identifier_FDD51             -2,803.42
# Item_Identifier_FDD52             -1,161.33
# Item_Identifier_FDD53             -2,029.47
# Item_Identifier_FDD56              1,179.38
# Item_Identifier_FDD57             -1,417.17
# Item_Identifier_FDD58               -956.91
# Item_Identifier_FDD59             -2,095.91
# Item_Identifier_FDE02             -1,014.61
# Item_Identifier_FDE04              1,040.28
# Item_Identifier_FDE05                244.81
# Item_Identifier_FDE08                413.70
# Item_Identifier_FDE09             -1,198.87
# Item_Identifier_FDE10               -670.18
# Item_Identifier_FDE11              1,867.55
# Item_Identifier_FDE14               -651.48
# Item_Identifier_FDE16              2,642.50
# Item_Identifier_FDE17                441.61
# Item_Identifier_FDE20              1,407.22
# Item_Identifier_FDE21               -889.79
# Item_Identifier_FDE22                432.88
# Item_Identifier_FDE23             -2,692.48
# Item_Identifier_FDE24               -214.38
# Item_Identifier_FDE26                191.15
# Item_Identifier_FDE28              2,227.29
# Item_Identifier_FDE29             -2,148.77
# Item_Identifier_FDE32             -3,414.54
# Item_Identifier_FDE33             -1,704.71
# Item_Identifier_FDE34              1,936.35
# Item_Identifier_FDE35             -2,936.56
# Item_Identifier_FDE36              1,798.77
# Item_Identifier_FDE38              1,078.50
# Item_Identifier_FDE39                150.54
# Item_Identifier_FDE40             -1,992.54
# Item_Identifier_FDE41             -1,485.48
# Item_Identifier_FDE44             -2,670.69
# Item_Identifier_FDE45              1,543.73
# Item_Identifier_FDE46               -592.50
# Item_Identifier_FDE47               -937.37
# Item_Identifier_FDE50              2,373.27
# Item_Identifier_FDE51             -2,734.27
# Item_Identifier_FDE52               -973.13
# Item_Identifier_FDE53             -1,030.38
# Item_Identifier_FDE56             -1,720.41
# Item_Identifier_FDE57                526.76
# Item_Identifier_FDE58                462.79
# Item_Identifier_FDE59             -3,021.86
# Item_Identifier_FDF02             -1,183.06
# Item_Identifier_FDF04              2,852.62
# Item_Identifier_FDF05              3,646.97
# Item_Identifier_FDF08             -1,451.50
# Item_Identifier_FDF09             -3,544.52
# Item_Identifier_FDF10               -278.11
# Item_Identifier_FDF11              1,433.46
# Item_Identifier_FDF12                422.45
# Item_Identifier_FDF14                211.54
# Item_Identifier_FDF16                -96.71
# Item_Identifier_FDF17              1,794.16
# Item_Identifier_FDF20                649.66
# Item_Identifier_FDF21                981.33
# Item_Identifier_FDF22              2,353.95
# Item_Identifier_FDF24             -1,063.20
# Item_Identifier_FDF26                 92.54
# Item_Identifier_FDF28               -625.74
# Item_Identifier_FDF29               -471.39
# Item_Identifier_FDF32              1,453.88
# Item_Identifier_FDF33               -894.36
# Item_Identifier_FDF34              1,580.99
# Item_Identifier_FDF35             -1,284.86
# Item_Identifier_FDF38             -3,080.28
# Item_Identifier_FDF39              4,871.78
# Item_Identifier_FDF40              2,755.29
# Item_Identifier_FDF41              3,627.48
# Item_Identifier_FDF44                572.07
# Item_Identifier_FDF45             -2,223.71
# Item_Identifier_FDF46               -610.61
# Item_Identifier_FDF47                940.69
# Item_Identifier_FDF50              1,381.89
# Item_Identifier_FDF52                796.43
# Item_Identifier_FDF53              1,693.09
# Item_Identifier_FDF56              1,501.09
# Item_Identifier_FDF57                222.00
# Item_Identifier_FDF58             -2,105.36
# Item_Identifier_FDF59             -1,076.35
# Item_Identifier_FDG02                206.65
# Item_Identifier_FDG04              1,269.76
# Item_Identifier_FDG05               -465.31
# Item_Identifier_FDG08                910.59
# Item_Identifier_FDG09              1,463.82
# Item_Identifier_FDG10             -2,730.29
# Item_Identifier_FDG12               -242.77
# Item_Identifier_FDG14              1,822.20
# Item_Identifier_FDG16              1,487.19
# Item_Identifier_FDG17              5,375.74
# Item_Identifier_FDG20               -203.10
# Item_Identifier_FDG21              1,130.45
# Item_Identifier_FDG22             -3,170.90
# Item_Identifier_FDG24             -1,452.06
# Item_Identifier_FDG26              2,670.44
# Item_Identifier_FDG28                 58.57
# Item_Identifier_FDG29             -3,105.48
# Item_Identifier_FDG31             -2,654.56
# Item_Identifier_FDG32              3,481.11
# Item_Identifier_FDG33                545.83
# Item_Identifier_FDG34             -1,189.02
# Item_Identifier_FDG35             -1,206.93
# Item_Identifier_FDG38             -1,041.35
# Item_Identifier_FDG40             -2,675.45
# Item_Identifier_FDG41             -1,043.71
# Item_Identifier_FDG44             -1,969.41
# Item_Identifier_FDG45              2,883.38
# Item_Identifier_FDG46               -199.27
# Item_Identifier_FDG47              2,900.58
# Item_Identifier_FDG50             -1,247.64
# Item_Identifier_FDG52             -2,741.41
# Item_Identifier_FDG53               -267.03
# Item_Identifier_FDG56             -2,122.58
# Item_Identifier_FDG57             -2,751.98
# Item_Identifier_FDG58               -190.48
# Item_Identifier_FDG59             -3,315.46
# Item_Identifier_FDG60              2,883.77
# Item_Identifier_FDH02             -2,017.17
# Item_Identifier_FDH04             -1,539.15
# Item_Identifier_FDH05              2,924.95
# Item_Identifier_FDH08                684.33
# Item_Identifier_FDH09             -3,316.26
# Item_Identifier_FDH10               -183.24
# Item_Identifier_FDH12               -691.59
# Item_Identifier_FDH14               -175.96
# Item_Identifier_FDH16             -1,612.89
# Item_Identifier_FDH17               -940.56
# Item_Identifier_FDH19              1,142.00
# Item_Identifier_FDH20               -892.11
# Item_Identifier_FDH21                902.21
# Item_Identifier_FDH22             -1,552.66
# Item_Identifier_FDH24                592.40
# Item_Identifier_FDH26               -512.82
# Item_Identifier_FDH27               -282.33
# Item_Identifier_FDH28             -2,584.57
# Item_Identifier_FDH31             -1,805.59
# Item_Identifier_FDH32               -920.66
# Item_Identifier_FDH33             -2,596.43
# Item_Identifier_FDH34                837.70
# Item_Identifier_FDH35                156.70
# Item_Identifier_FDH38                670.75
# Item_Identifier_FDH40             -1,748.40
# Item_Identifier_FDH41              1,680.89
# Item_Identifier_FDH44               -245.24
# Item_Identifier_FDH45             -2,903.01
# Item_Identifier_FDH46             -1,476.35
# Item_Identifier_FDH47             -1,208.76
# Item_Identifier_FDH48               -927.55
# Item_Identifier_FDH50              1,294.57
# Item_Identifier_FDH52             -2,105.07
# Item_Identifier_FDH53             -1,301.42
# Item_Identifier_FDH56               -758.86
# Item_Identifier_FDH57               -270.29
# Item_Identifier_FDH58               -495.11
# Item_Identifier_FDH60              1,749.42
# Item_Identifier_FDI02                566.67
# Item_Identifier_FDI04              1,507.95
# Item_Identifier_FDI05             -1,496.57
# Item_Identifier_FDI07              1,847.32
# Item_Identifier_FDI08              1,946.09
# Item_Identifier_FDI09              2,996.46
# Item_Identifier_FDI10                671.94
# Item_Identifier_FDI12             -1,180.60
# Item_Identifier_FDI14               -459.28
# Item_Identifier_FDI15              3,321.92
# Item_Identifier_FDI16             -2,050.34
# Item_Identifier_FDI19              2,852.27
# Item_Identifier_FDI20              2,294.50
# Item_Identifier_FDI21             -2,221.72
# Item_Identifier_FDI22              1,948.42
# Item_Identifier_FDI24              2,489.13
# Item_Identifier_FDI26              1,167.64
# Item_Identifier_FDI27             -3,245.79
# Item_Identifier_FDI28             -2,093.51
# Item_Identifier_FDI32               -323.88
# Item_Identifier_FDI33               -907.63
# Item_Identifier_FDI34              2,840.84
# Item_Identifier_FDI35              1,992.36
# Item_Identifier_FDI36              1,767.29
# Item_Identifier_FDI38              3,555.56
# Item_Identifier_FDI40               -997.40
# Item_Identifier_FDI41                793.35
# Item_Identifier_FDI44             -2,223.39
# Item_Identifier_FDI45                877.10
# Item_Identifier_FDI46              1,496.44
# Item_Identifier_FDI48             -2,472.40
# Item_Identifier_FDI50              4,114.26
# Item_Identifier_FDI52               -449.05
# Item_Identifier_FDI53               -222.16
# Item_Identifier_FDI56             -1,033.00
# Item_Identifier_FDI57              2,276.62
# Item_Identifier_FDI58             -1,523.52
# Item_Identifier_FDI60             -1,519.71
# Item_Identifier_FDJ02               -459.33
# Item_Identifier_FDJ03             -2,115.11
# Item_Identifier_FDJ04               -989.29
# Item_Identifier_FDJ07             -1,073.30
# Item_Identifier_FDJ08              1,521.91
# Item_Identifier_FDJ09             -2,853.21
# Item_Identifier_FDJ10                 15.65
# Item_Identifier_FDJ12              2,288.38
# Item_Identifier_FDJ14             -1,632.73
# Item_Identifier_FDJ15              4,076.52
# Item_Identifier_FDJ16             -1,919.88
# Item_Identifier_FDJ20               -828.91
# Item_Identifier_FDJ21              1,400.25
# Item_Identifier_FDJ22                226.69
# Item_Identifier_FDJ26                840.70
# Item_Identifier_FDJ27             -1,034.94
# Item_Identifier_FDJ28              1,452.65
# Item_Identifier_FDJ32             -2,903.76
# Item_Identifier_FDJ33               -475.98
# Item_Identifier_FDJ34             -1,461.99
# Item_Identifier_FDJ36               -898.35
# Item_Identifier_FDJ38              1,498.26
# Item_Identifier_FDJ40               -665.72
# Item_Identifier_FDJ41              2,533.91
# Item_Identifier_FDJ44                568.50
# Item_Identifier_FDJ45             -2,935.26
# Item_Identifier_FDJ46                928.58
# Item_Identifier_FDJ48              3,221.44
# Item_Identifier_FDJ50             -2,113.65
# Item_Identifier_FDJ52                174.92
# Item_Identifier_FDJ53               -990.99
# Item_Identifier_FDJ55              2,869.25
# Item_Identifier_FDJ56             -1,461.99
# Item_Identifier_FDJ57              1,411.84
# Item_Identifier_FDJ58              1,273.59
# Item_Identifier_FDJ60                555.72
# Item_Identifier_FDK02               -343.13
# Item_Identifier_FDK03              3,183.09
# Item_Identifier_FDK04             -1,957.03
# Item_Identifier_FDK08             -1,349.81
# Item_Identifier_FDK09              2,207.07
# Item_Identifier_FDK10                191.84
# Item_Identifier_FDK14             -1,908.29
# Item_Identifier_FDK15               -357.22
# Item_Identifier_FDK16             -1,117.06
# Item_Identifier_FDK20                 63.29
# Item_Identifier_FDK21              2,633.60
# Item_Identifier_FDK22              1,109.98
# Item_Identifier_FDK24             -2,120.58
# Item_Identifier_FDK25              1,697.55
# Item_Identifier_FDK26              1,652.21
# Item_Identifier_FDK27               -603.64
# Item_Identifier_FDK28              2,976.79
# Item_Identifier_FDK32                788.52
# Item_Identifier_FDK33              1,942.75
# Item_Identifier_FDK34              2,602.16
# Item_Identifier_FDK36             -2,414.02
# Item_Identifier_FDK38                938.08
# Item_Identifier_FDK40              3,992.21
# Item_Identifier_FDK41             -1,634.36
# Item_Identifier_FDK43               -429.87
# Item_Identifier_FDK44                 75.14
# Item_Identifier_FDK45             -1,533.59
# Item_Identifier_FDK46              2,313.42
# Item_Identifier_FDK48             -1,371.45
# Item_Identifier_FDK50              1,073.95
# Item_Identifier_FDK51              2,936.38
# Item_Identifier_FDK52              2,937.15
# Item_Identifier_FDK55             -1,721.70
# Item_Identifier_FDK56                951.51
# Item_Identifier_FDK58             -1,214.49
# Item_Identifier_FDK60             -1,249.45
# Item_Identifier_FDL02               -202.73
# Item_Identifier_FDL03                794.03
# Item_Identifier_FDL04               -780.25
# Item_Identifier_FDL08              2,139.98
# Item_Identifier_FDL09                253.86
# Item_Identifier_FDL10             -1,340.22
# Item_Identifier_FDL12             -2,672.50
# Item_Identifier_FDL13              2,761.23
# Item_Identifier_FDL14               -388.30
# Item_Identifier_FDL15               -125.58
# Item_Identifier_FDL16             -2,142.76
# Item_Identifier_FDL20               -741.06
# Item_Identifier_FDL21             -2,476.78
# Item_Identifier_FDL22             -1,592.79
# Item_Identifier_FDL24              2,132.49
# Item_Identifier_FDL25             -1,862.65
# Item_Identifier_FDL26              1,853.40
# Item_Identifier_FDL27             -2,231.98
# Item_Identifier_FDL28              1,295.15
# Item_Identifier_FDL32             -1,286.74
# Item_Identifier_FDL33                655.16
# Item_Identifier_FDL34                607.91
# Item_Identifier_FDL36             -1,235.60
# Item_Identifier_FDL38             -1,107.20
# Item_Identifier_FDL39               -810.75
# Item_Identifier_FDL40               -822.83
# Item_Identifier_FDL43             -1,869.56
# Item_Identifier_FDL44                995.26
# Item_Identifier_FDL45                 94.10
# Item_Identifier_FDL46             -1,924.46
# Item_Identifier_FDL48             -2,449.21
# Item_Identifier_FDL50             -1,241.23
# Item_Identifier_FDL51              1,430.15
# Item_Identifier_FDL52             -2,760.32
# Item_Identifier_FDL56             -1,429.10
# Item_Identifier_FDL57              3,672.77
# Item_Identifier_FDL58              3,240.13
# Item_Identifier_FDM01               -613.34
# Item_Identifier_FDM02             -1,169.36
# Item_Identifier_FDM03             -1,394.56
# Item_Identifier_FDM04             -2,279.29
# Item_Identifier_FDM08              2,423.27
# Item_Identifier_FDM09               -126.49
# Item_Identifier_FDM10              1,064.57
# Item_Identifier_FDM12                124.60
# Item_Identifier_FDM13             -1,313.86
# Item_Identifier_FDM14               -989.21
# Item_Identifier_FDM15                552.45
# Item_Identifier_FDM20              2,865.21
# Item_Identifier_FDM21              3,638.73
# Item_Identifier_FDM22             -2,339.35
# Item_Identifier_FDM24                543.19
# Item_Identifier_FDM25              1,338.08
# Item_Identifier_FDM27                 80.68
# Item_Identifier_FDM28                340.97
# Item_Identifier_FDM32             -1,545.18
# Item_Identifier_FDM33              1,451.50
# Item_Identifier_FDM34               -426.54
# Item_Identifier_FDM36                642.19
# Item_Identifier_FDM38             -1,997.93
# Item_Identifier_FDM39              2,188.80
# Item_Identifier_FDM40                502.40
# Item_Identifier_FDM44             -1,305.10
# Item_Identifier_FDM45               -606.37
# Item_Identifier_FDM46             -1,650.36
# Item_Identifier_FDM50             -2,436.66
# Item_Identifier_FDM51             -1,255.94
# Item_Identifier_FDM52                218.96
# Item_Identifier_FDM56             -1,749.13
# Item_Identifier_FDM57             -1,764.40
# Item_Identifier_FDM58               -433.39
# Item_Identifier_FDM60             -2,463.14
# Item_Identifier_FDN01              1,079.74
# Item_Identifier_FDN02              2,618.17
# Item_Identifier_FDN03              1,913.31
# Item_Identifier_FDN04                721.17
# Item_Identifier_FDN08               -663.95
# Item_Identifier_FDN09              1,835.48
# Item_Identifier_FDN10             -1,491.63
# Item_Identifier_FDN12               -337.68
# Item_Identifier_FDN13             -1,544.57
# Item_Identifier_FDN15               -548.52
# Item_Identifier_FDN16             -1,055.25
# Item_Identifier_FDN20                815.51
# Item_Identifier_FDN21               -137.10
# Item_Identifier_FDN22              2,189.55
# Item_Identifier_FDN23                289.14
# Item_Identifier_FDN24             -2,039.95
# Item_Identifier_FDN25             -2,199.33
# Item_Identifier_FDN27             -1,039.28
# Item_Identifier_FDN28             -2,292.74
# Item_Identifier_FDN31                481.58
# Item_Identifier_FDN32              1,391.12
# Item_Identifier_FDN33             -1,821.01
# Item_Identifier_FDN34              1,217.23
# Item_Identifier_FDN38              3,399.93
# Item_Identifier_FDN39                499.04
# Item_Identifier_FDN40                436.90
# Item_Identifier_FDN44                566.18
# Item_Identifier_FDN45              1,834.89
# Item_Identifier_FDN46             -1,267.66
# Item_Identifier_FDN48               -817.79
# Item_Identifier_FDN49             -2,636.65
# Item_Identifier_FDN50             -1,989.60
# Item_Identifier_FDN51              3,413.24
# Item_Identifier_FDN56                425.83
# Item_Identifier_FDN57               -479.50
# Item_Identifier_FDN58              2,679.91
# Item_Identifier_FDN60              1,300.09
# Item_Identifier_FDO01               -893.09
# Item_Identifier_FDO03              3,949.60
# Item_Identifier_FDO04             -2,770.10
# Item_Identifier_FDO08                249.94
# Item_Identifier_FDO09              2,653.80
# Item_Identifier_FDO10             -2,449.46
# Item_Identifier_FDO11              5,734.79
# Item_Identifier_FDO12              1,820.24
# Item_Identifier_FDO13                266.49
# Item_Identifier_FDO15             -1,680.68
# Item_Identifier_FDO16               -698.53
# Item_Identifier_FDO19             -2,497.62
# Item_Identifier_FDO20              2,469.95
# Item_Identifier_FDO21                845.02
# Item_Identifier_FDO22             -2,070.61
# Item_Identifier_FDO23             -1,169.54
# Item_Identifier_FDO24                738.23
# Item_Identifier_FDO25              1,314.64
# Item_Identifier_FDO27             -1,152.34
# Item_Identifier_FDO28             -3,317.22
# Item_Identifier_FDO31             -2,123.37
# Item_Identifier_FDO32             -2,731.61
# Item_Identifier_FDO33               -542.06
# Item_Identifier_FDO34              1,533.33
# Item_Identifier_FDO36              1,180.27
# Item_Identifier_FDO37              2,644.30
# Item_Identifier_FDO38             -1,746.42
# Item_Identifier_FDO39              2,002.55
# Item_Identifier_FDO40                255.08
# Item_Identifier_FDO44               -951.32
# Item_Identifier_FDO45             -1,991.60
# Item_Identifier_FDO46              1,027.98
# Item_Identifier_FDO48              2,183.82
# Item_Identifier_FDO49             -2,196.51
# Item_Identifier_FDO50             -1,449.83
# Item_Identifier_FDO51             -3,044.99
# Item_Identifier_FDO52                471.15
# Item_Identifier_FDO56               -990.23
# Item_Identifier_FDO57                531.78
# Item_Identifier_FDO58                218.26
# Item_Identifier_FDO60             -2,441.41
# Item_Identifier_FDP01                -61.38
# Item_Identifier_FDP03                -76.33
# Item_Identifier_FDP04             -2,432.65
# Item_Identifier_FDP07                825.25
# Item_Identifier_FDP08              1,159.45
# Item_Identifier_FDP09              1,828.74
# Item_Identifier_FDP10             -1,037.62
# Item_Identifier_FDP11                849.70
# Item_Identifier_FDP12             -2,817.64
# Item_Identifier_FDP13             -3,375.39
# Item_Identifier_FDP15              4,571.88
# Item_Identifier_FDP16              3,798.53
# Item_Identifier_FDP19               -107.77
# Item_Identifier_FDP20             -1,312.50
# Item_Identifier_FDP21              1,483.63
# Item_Identifier_FDP22             -2,956.74
# Item_Identifier_FDP23              2,051.98
# Item_Identifier_FDP24               -312.75
# Item_Identifier_FDP25              2,147.47
# Item_Identifier_FDP26             -1,004.19
# Item_Identifier_FDP27              1,592.04
# Item_Identifier_FDP28              2,428.08
# Item_Identifier_FDP31             -2,582.03
# Item_Identifier_FDP32               -702.61
# Item_Identifier_FDP33              3,487.58
# Item_Identifier_FDP34                869.67
# Item_Identifier_FDP36             -2,212.22
# Item_Identifier_FDP37                349.60
# Item_Identifier_FDP38             -2,787.15
# Item_Identifier_FDP39             -2,194.90
# Item_Identifier_FDP40               -803.36
# Item_Identifier_FDP44             -1,195.84
# Item_Identifier_FDP45              1,692.60
# Item_Identifier_FDP46             -1,271.94
# Item_Identifier_FDP48              2,676.91
# Item_Identifier_FDP49             -2,080.06
# Item_Identifier_FDP51                 -1.67
# Item_Identifier_FDP52              3,313.15
# Item_Identifier_FDP56             -2,935.15
# Item_Identifier_FDP57             -1,590.95
# Item_Identifier_FDP58              1,904.20
# Item_Identifier_FDP59             -1,320.42
# Item_Identifier_FDP60               -724.68
# Item_Identifier_FDQ01              2,585.60
# Item_Identifier_FDQ03              1,097.56
# Item_Identifier_FDQ04             -1,253.14
# Item_Identifier_FDQ07              1,758.55
# Item_Identifier_FDQ08             -2,012.65
# Item_Identifier_FDQ09               -886.52
# Item_Identifier_FDQ10              1,439.05
# Item_Identifier_FDQ11              1,559.11
# Item_Identifier_FDQ12              2,029.98
# Item_Identifier_FDQ13             -1,279.61
# Item_Identifier_FDQ14                -80.32
# Item_Identifier_FDQ15             -1,543.14
# Item_Identifier_FDQ16               -586.56
# Item_Identifier_FDQ19              3,445.17
# Item_Identifier_FDQ20             -3,129.10
# Item_Identifier_FDQ21                -39.12
# Item_Identifier_FDQ22             -3,402.18
# Item_Identifier_FDQ23               -775.32
# Item_Identifier_FDQ24              3,662.23
# Item_Identifier_FDQ25                692.96
# Item_Identifier_FDQ26             -2,551.18
# Item_Identifier_FDQ27               -839.48
# Item_Identifier_FDQ28                171.76
# Item_Identifier_FDQ31             -1,578.86
# Item_Identifier_FDQ32               -371.52
# Item_Identifier_FDQ33              2,039.93
# Item_Identifier_FDQ34             -1,245.53
# Item_Identifier_FDQ36             -2,162.96
# Item_Identifier_FDQ37              3,505.28
# Item_Identifier_FDQ39              1,939.34
# Item_Identifier_FDQ40                772.37
# Item_Identifier_FDQ44                629.26
# Item_Identifier_FDQ45                768.21
# Item_Identifier_FDQ46               -658.71
# Item_Identifier_FDQ47             -2,387.84
# Item_Identifier_FDQ48             -1,517.67
# Item_Identifier_FDQ49               -625.43
# Item_Identifier_FDQ51             -2,490.34
# Item_Identifier_FDQ52              4,289.15
# Item_Identifier_FDQ55             -1,141.19
# Item_Identifier_FDQ56             -1,222.14
# Item_Identifier_FDQ57                145.68
# Item_Identifier_FDQ58               -237.79
# Item_Identifier_FDQ59             -1,905.63
# Item_Identifier_FDQ60               -138.62
# Item_Identifier_FDR01              1,888.73
# Item_Identifier_FDR02               -537.83
# Item_Identifier_FDR03              2,519.04
# Item_Identifier_FDR04             -1,046.72
# Item_Identifier_FDR07             -1,556.68
# Item_Identifier_FDR08               -768.06
# Item_Identifier_FDR09              2,941.27
# Item_Identifier_FDR10                276.13
# Item_Identifier_FDR11                449.71
# Item_Identifier_FDR12                471.33
# Item_Identifier_FDR13             -1,617.11
# Item_Identifier_FDR14             -2,470.92
# Item_Identifier_FDR15                624.86
# Item_Identifier_FDR16              5,760.60
# Item_Identifier_FDR19                620.99
# Item_Identifier_FDR20             -2,573.27
# Item_Identifier_FDR21                361.04
# Item_Identifier_FDR22               -445.35
# Item_Identifier_FDR23              1,677.01
# Item_Identifier_FDR24             -1,615.79
# Item_Identifier_FDR25              1,624.47
# Item_Identifier_FDR26                -65.00
# Item_Identifier_FDR27                 -4.78
# Item_Identifier_FDR28                635.47
# Item_Identifier_FDR31                265.89
# Item_Identifier_FDR32              2,734.98
# Item_Identifier_FDR33               -796.82
# Item_Identifier_FDR34              4,181.35
# Item_Identifier_FDR35              2,070.31
# Item_Identifier_FDR36             -2,071.46
# Item_Identifier_FDR37              2,467.50
# Item_Identifier_FDR39              1,900.23
# Item_Identifier_FDR40             -1,835.21
# Item_Identifier_FDR43             -2,792.21
# Item_Identifier_FDR44               -933.46
# Item_Identifier_FDR45              4,762.17
# Item_Identifier_FDR46                271.17
# Item_Identifier_FDR47              1,414.91
# Item_Identifier_FDR48                288.62
# Item_Identifier_FDR49             -2,314.06
# Item_Identifier_FDR51                315.20
# Item_Identifier_FDR52              2,310.41
# Item_Identifier_FDR55              1,881.79
# Item_Identifier_FDR56              2,340.10
# Item_Identifier_FDR57               -210.46
# Item_Identifier_FDR58             -1,455.42
# Item_Identifier_FDR59              2,039.22
# Item_Identifier_FDR60             -2,069.71
# Item_Identifier_FDS01              1,167.85
# Item_Identifier_FDS02              1,827.81
# Item_Identifier_FDS03             -1,706.03
# Item_Identifier_FDS04                366.30
# Item_Identifier_FDS07             -1,157.25
# Item_Identifier_FDS08               -296.51
# Item_Identifier_FDS09             -2,800.24
# Item_Identifier_FDS10                765.19
# Item_Identifier_FDS11              2,050.09
# Item_Identifier_FDS12                854.16
# Item_Identifier_FDS13              2,352.48
# Item_Identifier_FDS14               -635.64
# Item_Identifier_FDS15               -274.14
# Item_Identifier_FDS16                685.51
# Item_Identifier_FDS19             -1,786.54
# Item_Identifier_FDS20                962.22
# Item_Identifier_FDS21             -2,090.11
# Item_Identifier_FDS22             -2,922.45
# Item_Identifier_FDS23                 60.60
# Item_Identifier_FDS24             -1,106.19
# Item_Identifier_FDS25             -1,085.76
# Item_Identifier_FDS26              3,633.47
# Item_Identifier_FDS27                 52.62
# Item_Identifier_FDS28             -2,766.65
# Item_Identifier_FDS31              1,033.74
# Item_Identifier_FDS32               -618.83
# Item_Identifier_FDS33             -1,240.24
# Item_Identifier_FDS34             -1,007.44
# Item_Identifier_FDS35             -2,157.49
# Item_Identifier_FDS36                300.83
# Item_Identifier_FDS37               -827.27
# Item_Identifier_FDS39                444.06
# Item_Identifier_FDS40             -2,543.98
# Item_Identifier_FDS43                695.56
# Item_Identifier_FDS44              3,380.64
# Item_Identifier_FDS45               -392.31
# Item_Identifier_FDS46               -869.91
# Item_Identifier_FDS47             -1,749.37
# Item_Identifier_FDS48                291.31
# Item_Identifier_FDS49             -1,316.30
# Item_Identifier_FDS50                119.59
# Item_Identifier_FDS51             -2,598.98
# Item_Identifier_FDS52             -1,193.70
# Item_Identifier_FDS55                579.65
# Item_Identifier_FDS56              2,800.78
# Item_Identifier_FDS57               -243.37
# Item_Identifier_FDS58              1,097.69
# Item_Identifier_FDS59               -133.78
# Item_Identifier_FDS60                119.68
# Item_Identifier_FDT01              1,581.79
# Item_Identifier_FDT02             -3,107.14
# Item_Identifier_FDT03                 89.74
# Item_Identifier_FDT04             -2,068.44
# Item_Identifier_FDT07              2,166.29
# Item_Identifier_FDT08                 18.83
# Item_Identifier_FDT09               -235.43
# Item_Identifier_FDT10             -2,453.28
# Item_Identifier_FDT11                569.59
# Item_Identifier_FDT12              1,894.80
# Item_Identifier_FDT13              1,457.30
# Item_Identifier_FDT14               -164.05
# Item_Identifier_FDT15                782.26
# Item_Identifier_FDT16              4,577.15
# Item_Identifier_FDT19              1,271.78
# Item_Identifier_FDT20             -2,987.22
# Item_Identifier_FDT21              2,863.97
# Item_Identifier_FDT22             -2,218.90
# Item_Identifier_FDT23             -1,962.98
# Item_Identifier_FDT24             -1,137.82
# Item_Identifier_FDT25               -138.65
# Item_Identifier_FDT26               -969.82
# Item_Identifier_FDT27              2,470.50
# Item_Identifier_FDT28                551.00
# Item_Identifier_FDT31                691.76
# Item_Identifier_FDT32              1,089.02
# Item_Identifier_FDT33                197.78
# Item_Identifier_FDT34             -1,244.77
# Item_Identifier_FDT35               -256.04
# Item_Identifier_FDT36             -2,187.97
# Item_Identifier_FDT37              3,083.96
# Item_Identifier_FDT39                -44.56
# Item_Identifier_FDT40               -885.53
# Item_Identifier_FDT43             -2,313.91
# Item_Identifier_FDT44               -469.73
# Item_Identifier_FDT45             -2,236.61
# Item_Identifier_FDT46             -2,609.04
# Item_Identifier_FDT47             -1,031.39
# Item_Identifier_FDT48              1,408.52
# Item_Identifier_FDT49             -1,021.31
# Item_Identifier_FDT50             -1,764.85
# Item_Identifier_FDT51               -564.34
# Item_Identifier_FDT52              2,435.32
# Item_Identifier_FDT55                715.90
# Item_Identifier_FDT56             -2,377.95
# Item_Identifier_FDT57              2,485.26
# Item_Identifier_FDT58                237.36
# Item_Identifier_FDT59              2,028.91
# Item_Identifier_FDT60                114.65
# Item_Identifier_FDU01              1,344.20
# Item_Identifier_FDU02              2,734.76
# Item_Identifier_FDU03                -87.00
# Item_Identifier_FDU04               -782.70
# Item_Identifier_FDU07                265.47
# Item_Identifier_FDU08             -1,615.32
# Item_Identifier_FDU09             -1,841.28
# Item_Identifier_FDU10             -2,849.67
# Item_Identifier_FDU11               -563.15
# Item_Identifier_FDU12              3,030.03
# Item_Identifier_FDU13                256.82
# Item_Identifier_FDU14              1,179.16
# Item_Identifier_FDU15             -2,816.87
# Item_Identifier_FDU16             -1,255.41
# Item_Identifier_FDU19                 79.67
# Item_Identifier_FDU20               -463.59
# Item_Identifier_FDU21             -3,181.69
# Item_Identifier_FDU22                154.41
# Item_Identifier_FDU23                363.51
# Item_Identifier_FDU24               -222.65
# Item_Identifier_FDU25             -2,209.81
# Item_Identifier_FDU26             -1,303.43
# Item_Identifier_FDU27             -2,300.80
# Item_Identifier_FDU28                725.87
# Item_Identifier_FDU31              1,378.37
# Item_Identifier_FDU32               -690.13
# Item_Identifier_FDU33             -2,340.33
# Item_Identifier_FDU34               -282.74
# Item_Identifier_FDU35               -643.19
# Item_Identifier_FDU36               -477.69
# Item_Identifier_FDU37             -1,207.67
# Item_Identifier_FDU38              1,698.13
# Item_Identifier_FDU39             -2,176.03
# Item_Identifier_FDU40              1,115.50
# Item_Identifier_FDU43                703.01
# Item_Identifier_FDU44              1,185.62
# Item_Identifier_FDU45             -1,049.37
# Item_Identifier_FDU46             -1,516.90
# Item_Identifier_FDU47               -672.13
# Item_Identifier_FDU48               -570.24
# Item_Identifier_FDU49               -940.29
# Item_Identifier_FDU50             -1,282.59
# Item_Identifier_FDU51              2,131.54
# Item_Identifier_FDU52                -11.82
# Item_Identifier_FDU55              6,640.59
# Item_Identifier_FDU56               -101.82
# Item_Identifier_FDU57                 83.78
# Item_Identifier_FDU58                146.70
# Item_Identifier_FDU59                969.89
# Item_Identifier_FDU60              2,920.25
# Item_Identifier_FDV01                872.96
# Item_Identifier_FDV02                247.71
# Item_Identifier_FDV03                649.92
# Item_Identifier_FDV04               -715.12
# Item_Identifier_FDV07             -1,353.40
# Item_Identifier_FDV08             -3,227.94
# Item_Identifier_FDV09                 95.46
# Item_Identifier_FDV10             -2,430.43
# Item_Identifier_FDV11                782.81
# Item_Identifier_FDV12               -206.64
# Item_Identifier_FDV13             -1,498.96
# Item_Identifier_FDV14             -1,981.78
# Item_Identifier_FDV15                -69.57
# Item_Identifier_FDV16             -2,654.02
# Item_Identifier_FDV19                793.03
# Item_Identifier_FDV20               -215.99
# Item_Identifier_FDV21               -287.99
# Item_Identifier_FDV22                564.14
# Item_Identifier_FDV23               -171.80
# Item_Identifier_FDV24                857.43
# Item_Identifier_FDV25              3,331.80
# Item_Identifier_FDV26              1,351.86
# Item_Identifier_FDV27             -1,222.25
# Item_Identifier_FDV28             -2,831.71
# Item_Identifier_FDV31                214.52
# Item_Identifier_FDV32             -1,876.03
# Item_Identifier_FDV33              2,644.54
# Item_Identifier_FDV34             -1,689.87
# Item_Identifier_FDV35              1,111.44
# Item_Identifier_FDV36                607.39
# Item_Identifier_FDV37                799.97
# Item_Identifier_FDV38             -2,172.71
# Item_Identifier_FDV39              2,187.70
# Item_Identifier_FDV40             -2,150.63
# Item_Identifier_FDV43             -3,307.08
# Item_Identifier_FDV44                  6.52
# Item_Identifier_FDV45              1,398.95
# Item_Identifier_FDV46               -163.25
# Item_Identifier_FDV47             -1,005.72
# Item_Identifier_FDV48               -961.01
# Item_Identifier_FDV49              3,554.24
# Item_Identifier_FDV50               -823.60
# Item_Identifier_FDV51                451.00
# Item_Identifier_FDV52               -655.18
# Item_Identifier_FDV55                -82.46
# Item_Identifier_FDV56             -1,602.99
# Item_Identifier_FDV57              2,012.41
# Item_Identifier_FDV58               -249.45
# Item_Identifier_FDV59              2,240.20
# Item_Identifier_FDV60              1,665.45
# Item_Identifier_FDW01               -799.49
# Item_Identifier_FDW02                160.93
# Item_Identifier_FDW03               -695.87
# Item_Identifier_FDW04                424.55
# Item_Identifier_FDW07             -1,933.76
# Item_Identifier_FDW08             -1,632.51
# Item_Identifier_FDW09             -2,237.76
# Item_Identifier_FDW10              3,355.26
# Item_Identifier_FDW11             -2,650.71
# Item_Identifier_FDW12                 90.89
# Item_Identifier_FDW13             -1,840.98
# Item_Identifier_FDW14             -1,581.12
# Item_Identifier_FDW15                279.24
# Item_Identifier_FDW16               -954.59
# Item_Identifier_FDW19             -1,176.43
# Item_Identifier_FDW20               -552.49
# Item_Identifier_FDW21             -1,525.89
# Item_Identifier_FDW22              2,541.59
# Item_Identifier_FDW23             -2,043.92
# Item_Identifier_FDW24             -1,750.63
# Item_Identifier_FDW25             -2,151.83
# Item_Identifier_FDW26              1,238.46
# Item_Identifier_FDW27               -369.77
# Item_Identifier_FDW28              1,605.85
# Item_Identifier_FDW31                719.10
# Item_Identifier_FDW32             -1,586.68
# Item_Identifier_FDW33             -1,173.82
# Item_Identifier_FDW34              2,656.44
# ...
# Item_Identifier_FDZ27             -2,306.36
# Item_Identifier_FDZ28               -404.23
# Item_Identifier_FDZ31              2,447.24
# Item_Identifier_FDZ32             -1,408.06
# Item_Identifier_FDZ33                 -5.91
# Item_Identifier_FDZ34              2,905.90
# Item_Identifier_FDZ35               -550.33
# Item_Identifier_FDZ36              2,082.50
# Item_Identifier_FDZ37             -2,153.44
# Item_Identifier_FDZ38              2,708.72
# Item_Identifier_FDZ39             -1,647.32
# Item_Identifier_FDZ40             -2,278.54
# Item_Identifier_FDZ43              3,712.80
# Item_Identifier_FDZ44             -1,161.08
# Item_Identifier_FDZ45              1,580.37
# Item_Identifier_FDZ46               -906.65
# Item_Identifier_FDZ47             -1,062.47
# Item_Identifier_FDZ48               -678.62
# Item_Identifier_FDZ49              1,870.07
# Item_Identifier_FDZ50              2,920.77
# Item_Identifier_FDZ51             -1,697.48
# Item_Identifier_FDZ52               -973.71
# Item_Identifier_FDZ55                609.53
# Item_Identifier_FDZ56                742.67
# Item_Identifier_FDZ57             -1,813.37
# Item_Identifier_FDZ58               -258.35
# Item_Identifier_FDZ59              1,597.67
# Item_Identifier_FDZ60             -1,367.55
# Item_Identifier_NCA05               -559.21
# Item_Identifier_NCA06             -3,104.51
# Item_Identifier_NCA17               -229.51
# Item_Identifier_NCA18             -1,142.10
# Item_Identifier_NCA29                763.85
# Item_Identifier_NCA30                743.92
# Item_Identifier_NCA41              1,815.44
# Item_Identifier_NCA42                559.22
# Item_Identifier_NCA53             -1,975.19
# Item_Identifier_NCA54                582.08
# Item_Identifier_NCB06                602.76
# Item_Identifier_NCB07              1,461.50
# Item_Identifier_NCB18             -1,202.42
# Item_Identifier_NCB19             -1,738.13
# Item_Identifier_NCB30                816.51
# Item_Identifier_NCB31              2,088.20
# Item_Identifier_NCB42               -529.08
# Item_Identifier_NCB43              1,865.86
# Item_Identifier_NCB54                506.23
# Item_Identifier_NCB55             -2,726.98
# Item_Identifier_NCC06                519.75
# Item_Identifier_NCC07             -1,750.94
# Item_Identifier_NCC18                355.97
# Item_Identifier_NCC19              1,558.46
# Item_Identifier_NCC30                 46.06
# Item_Identifier_NCC31                185.29
# Item_Identifier_NCC42               -144.09
# Item_Identifier_NCC43              1,745.35
# Item_Identifier_NCC54              3,116.40
# Item_Identifier_NCD06             -2,881.50
# Item_Identifier_NCD07             -1,721.16
# Item_Identifier_NCD18              3,070.24
# Item_Identifier_NCD19             -2,458.99
# Item_Identifier_NCD30             -2,162.31
# Item_Identifier_NCD31                308.74
# Item_Identifier_NCD42             -2,813.96
# Item_Identifier_NCD43             -1,717.45
# Item_Identifier_NCD54               -258.01
# Item_Identifier_NCD55             -3,631.55
# Item_Identifier_NCE06               -475.65
# Item_Identifier_NCE07               -882.67
# Item_Identifier_NCE18              3,485.96
# Item_Identifier_NCE19             -2,416.54
# Item_Identifier_NCE30                680.02
# Item_Identifier_NCE31             -3,442.61
# Item_Identifier_NCE42              3,715.96
# Item_Identifier_NCE43              1,462.18
# Item_Identifier_NCE54             -1,774.75
# Item_Identifier_NCE55              1,476.63
# Item_Identifier_NCF06              1,994.74
# Item_Identifier_NCF07             -1,576.62
# Item_Identifier_NCF18              1,000.07
# Item_Identifier_NCF19             -2,837.45
# Item_Identifier_NCF30               -672.94
# Item_Identifier_NCF31               -564.23
# Item_Identifier_NCF42                 71.07
# Item_Identifier_NCF43               -395.40
# Item_Identifier_NCF54                487.63
# Item_Identifier_NCF55             -2,910.18
# Item_Identifier_NCG06              2,018.72
# Item_Identifier_NCG07                898.49
# Item_Identifier_NCG18             -1,221.43
# Item_Identifier_NCG19                801.59
# Item_Identifier_NCG30               -692.00
# Item_Identifier_NCG42             -1,063.81
# Item_Identifier_NCG43             -1,261.83
# Item_Identifier_NCG54              1,317.54
# Item_Identifier_NCG55               -483.89
# Item_Identifier_NCH06              1,187.79
# Item_Identifier_NCH07                326.14
# Item_Identifier_NCH18              2,564.60
# Item_Identifier_NCH29               -414.63
# Item_Identifier_NCH30             -1,172.39
# Item_Identifier_NCH42              2,161.70
# Item_Identifier_NCH43                201.34
# Item_Identifier_NCH54                255.08
# Item_Identifier_NCH55               -929.63
# Item_Identifier_NCI06              1,410.33
# Item_Identifier_NCI17             -1,523.17
# Item_Identifier_NCI18              1,038.70
# Item_Identifier_NCI29               -401.68
# Item_Identifier_NCI30              1,666.21
# Item_Identifier_NCI31             -2,463.38
# Item_Identifier_NCI42                664.33
# Item_Identifier_NCI43             -3,143.01
# Item_Identifier_NCI54             -1,135.97
# Item_Identifier_NCI55                272.45
# Item_Identifier_NCJ05               -137.14
# Item_Identifier_NCJ06               -999.83
# Item_Identifier_NCJ17             -1,225.36
# Item_Identifier_NCJ18               -488.74
# Item_Identifier_NCJ19             -1,462.30
# Item_Identifier_NCJ29             -1,608.12
# Item_Identifier_NCJ30                330.24
# Item_Identifier_NCJ31              2,342.84
# Item_Identifier_NCJ42               -852.93
# Item_Identifier_NCJ43                 51.65
# Item_Identifier_NCJ54              3,064.69
# Item_Identifier_NCK05             -2,065.05
# Item_Identifier_NCK06             -1,631.46
# Item_Identifier_NCK07                848.45
# Item_Identifier_NCK17             -2,367.21
# Item_Identifier_NCK18                885.98
# Item_Identifier_NCK19              1,417.58
# Item_Identifier_NCK29               -186.77
# Item_Identifier_NCK30              1,937.85
# Item_Identifier_NCK31             -3,097.26
# Item_Identifier_NCK42              1,792.86
# Item_Identifier_NCK53               -458.12
# Item_Identifier_NCK54             -1,063.38
# Item_Identifier_NCL05             -2,562.66
# Item_Identifier_NCL06              2,658.44
# Item_Identifier_NCL07             -2,658.28
# Item_Identifier_NCL17                658.26
# Item_Identifier_NCL18                457.92
# Item_Identifier_NCL19                 56.75
# Item_Identifier_NCL29                781.85
# Item_Identifier_NCL30               -740.69
# Item_Identifier_NCL31              1,177.20
# Item_Identifier_NCL41             -2,567.30
# Item_Identifier_NCL42              4,136.33
# Item_Identifier_NCL53              1,647.29
# Item_Identifier_NCL54                898.53
# Item_Identifier_NCL55              2,939.37
# Item_Identifier_NCM05              3,896.29
# Item_Identifier_NCM06                -58.79
# Item_Identifier_NCM07             -1,351.24
# Item_Identifier_NCM17             -2,101.80
# Item_Identifier_NCM18             -2,060.27
# Item_Identifier_NCM19                 48.19
# Item_Identifier_NCM26                410.09
# Item_Identifier_NCM29                 28.82
# Item_Identifier_NCM30             -2,958.86
# Item_Identifier_NCM31                286.79
# Item_Identifier_NCM41             -1,785.75
# Item_Identifier_NCM42             -1,315.34
# Item_Identifier_NCM43                516.73
# Item_Identifier_NCM53               -982.59
# Item_Identifier_NCM54               -270.55
# Item_Identifier_NCM55              1,376.14
# Item_Identifier_NCN05              1,708.50
# Item_Identifier_NCN06                919.04
# Item_Identifier_NCN07               -190.63
# Item_Identifier_NCN14                975.96
# Item_Identifier_NCN17             -1,205.25
# Item_Identifier_NCN18               -190.15
# Item_Identifier_NCN19              1,109.35
# Item_Identifier_NCN26               -106.32
# Item_Identifier_NCN29             -2,355.58
# Item_Identifier_NCN30             -1,593.27
# Item_Identifier_NCN41               -125.03
# Item_Identifier_NCN42                -28.74
# Item_Identifier_NCN43               -109.41
# Item_Identifier_NCN53             -2,384.80
# Item_Identifier_NCN54             -2,557.44
# Item_Identifier_NCN55              4,076.06
# Item_Identifier_NCO02             -1,894.46
# Item_Identifier_NCO05               -766.79
# Item_Identifier_NCO06             -3,208.37
# Item_Identifier_NCO07              2,249.24
# Item_Identifier_NCO14             -3,453.53
# Item_Identifier_NCO17               -179.62
# Item_Identifier_NCO18              1,649.05
# Item_Identifier_NCO26               -518.56
# Item_Identifier_NCO29                772.22
# Item_Identifier_NCO30                450.65
# Item_Identifier_NCO41               -783.68
# Item_Identifier_NCO42                -35.43
# Item_Identifier_NCO43               -566.24
# Item_Identifier_NCO53              1,840.66
# Item_Identifier_NCO54             -2,439.84
# Item_Identifier_NCO55               -721.31
# Item_Identifier_NCP02             -2,708.24
# Item_Identifier_NCP05              1,132.67
# Item_Identifier_NCP06               -576.43
# Item_Identifier_NCP14               -526.26
# Item_Identifier_NCP17             -1,884.16
# Item_Identifier_NCP18                314.68
# Item_Identifier_NCP29             -2,066.48
# Item_Identifier_NCP30             -3,188.85
# Item_Identifier_NCP42              1,597.57
# Item_Identifier_NCP43                623.90
# Item_Identifier_NCP50             -1,844.37
# Item_Identifier_NCP53              2,686.58
# Item_Identifier_NCP54               -787.86
# Item_Identifier_NCP55             -1,682.76
# Item_Identifier_NCQ02              1,517.41
# Item_Identifier_NCQ05                629.80
# Item_Identifier_NCQ06              3,245.24
# Item_Identifier_NCQ17                585.44
# Item_Identifier_NCQ18             -1,090.11
# Item_Identifier_NCQ29              1,610.69
# Item_Identifier_NCQ30             -1,119.63
# Item_Identifier_NCQ38               -977.16
# Item_Identifier_NCQ41                877.86
# Item_Identifier_NCQ42               -737.04
# Item_Identifier_NCQ43             -1,285.32
# Item_Identifier_NCQ50              2,297.26
# Item_Identifier_NCQ53              3,781.97
# Item_Identifier_NCQ54              1,767.56
# Item_Identifier_NCR05              1,147.69
# Item_Identifier_NCR06             -3,013.53
# Item_Identifier_NCR17                -38.73
# Item_Identifier_NCR18             -3,319.12
# Item_Identifier_NCR29             -2,160.39
# Item_Identifier_NCR30             -2,194.00
# Item_Identifier_NCR38              2,793.43
# Item_Identifier_NCR41               -992.09
# Item_Identifier_NCR42             -3,605.05
# Item_Identifier_NCR50              2,720.91
# Item_Identifier_NCR53              2,403.34
# Item_Identifier_NCR54                893.94
# Item_Identifier_NCS05               -550.08
# Item_Identifier_NCS06              2,057.11
# Item_Identifier_NCS17             -1,035.65
# Item_Identifier_NCS18               -727.86
# Item_Identifier_NCS29              3,175.93
# Item_Identifier_NCS30               -152.02
# Item_Identifier_NCS38             -1,459.58
# Item_Identifier_NCS41                728.05
# Item_Identifier_NCS42               -831.57
# Item_Identifier_NCS53                552.78
# Item_Identifier_NCS54              1,954.81
# Item_Identifier_NCT05              3,961.58
# Item_Identifier_NCT06                519.08
# Item_Identifier_NCT17              1,803.59
# Item_Identifier_NCT18              1,084.81
# Item_Identifier_NCT29               -401.95
# Item_Identifier_NCT30             -2,629.10
# Item_Identifier_NCT41                410.74
# Item_Identifier_NCT42               -498.20
# Item_Identifier_NCT53               -115.76
# Item_Identifier_NCT54             -1,906.79
# Item_Identifier_NCU05               -926.99
# Item_Identifier_NCU06              1,545.08
# Item_Identifier_NCU17               -810.70
# Item_Identifier_NCU18               -380.33
# Item_Identifier_NCU29                840.47
# Item_Identifier_NCU30                977.11
# Item_Identifier_NCU41              2,314.31
# Item_Identifier_NCU42              1,408.10
# Item_Identifier_NCU53                158.07
# Item_Identifier_NCU54              1,992.67
# Item_Identifier_NCV05               -111.01
# Item_Identifier_NCV06              1,463.21
# Item_Identifier_NCV17                403.04
# Item_Identifier_NCV18               -322.33
# Item_Identifier_NCV29                993.70
# Item_Identifier_NCV30             -2,364.79
# Item_Identifier_NCV41               -898.80
# Item_Identifier_NCV42             -1,037.37
# Item_Identifier_NCV53              3,600.97
# Item_Identifier_NCV54             -1,282.30
# Item_Identifier_NCW05                801.92
# Item_Identifier_NCW06                626.91
# Item_Identifier_NCW17                656.43
# Item_Identifier_NCW18              5,116.66
# Item_Identifier_NCW29               -553.24
# Item_Identifier_NCW30              2,287.56
# Item_Identifier_NCW41                818.48
# Item_Identifier_NCW42              1,939.35
# Item_Identifier_NCW53                677.33
# Item_Identifier_NCW54             -2,522.32
# Item_Identifier_NCX05               -443.80
# Item_Identifier_NCX06                759.64
# Item_Identifier_NCX17              2,624.52
# Item_Identifier_NCX18                938.37
# Item_Identifier_NCX29                406.58
# Item_Identifier_NCX30              2,632.25
# Item_Identifier_NCX41              1,771.50
# Item_Identifier_NCX42                263.05
# Item_Identifier_NCX53                410.20
# Item_Identifier_NCX54             -1,252.54
# Item_Identifier_NCY05             -2,892.75
# Item_Identifier_NCY06             -1,276.17
# Item_Identifier_NCY17             -2,250.67
# Item_Identifier_NCY18                826.29
# Item_Identifier_NCY29             -2,028.13
# Item_Identifier_NCY30                913.91
# Item_Identifier_NCY41             -2,507.41
# Item_Identifier_NCY42                 92.22
# Item_Identifier_NCY53               -218.97
# Item_Identifier_NCY54                805.43
# Item_Identifier_NCZ05               -910.97
# Item_Identifier_NCZ06              2,048.80
# Item_Identifier_NCZ17             -2,207.64
# Item_Identifier_NCZ18              3,808.51
# Item_Identifier_NCZ29                185.04
# Item_Identifier_NCZ30               -843.16
# Item_Identifier_NCZ41               -507.62
# Item_Identifier_NCZ42              2,547.36
# Item_Identifier_NCZ53              1,589.26
# Item_Identifier_NCZ54              2,274.33
# Item_Fat_Content_Regular              79.33
# Item_Type_Breads                     293.87
# Item_Type_Breakfast                   82.92
# Item_Type_Canned                     306.72
# Item_Type_Dairy                      406.62
# Item_Type_Frozen Foods               246.18
# Item_Type_Fruits and Vegetables      470.06
# Item_Type_Hard Drinks                303.15
# Item_Type_Health and Hygiene         162.08
# Item_Type_Household                  620.00
# Item_Type_Meat                       303.06
# Item_Type_Others                     150.53
# Item_Type_Seafood                    583.94
# Item_Type_Snack Foods                456.31
# Item_Type_Soft Drinks               -224.20
# Item_Type_Starchy Foods              539.62
# Outlet_Identifier_OUT013             104.62
# Outlet_Identifier_OUT017             192.29
# Outlet_Identifier_OUT018             -37.56
# Outlet_Identifier_OUT019            -676.44
# Outlet_Identifier_OUT027             798.89
# Outlet_Identifier_OUT035             122.55
# Outlet_Identifier_OUT045             108.69
# Outlet_Identifier_OUT046             265.17
# Outlet_Identifier_OUT049            -140.75
# Outlet_Establishment_Year_1987       104.62
# Outlet_Establishment_Year_1997       265.17
# Outlet_Establishment_Year_1998      -737.45
# Outlet_Establishment_Year_1999      -140.75
# Outlet_Establishment_Year_2002       108.69
# Outlet_Establishment_Year_2004       122.55
# Outlet_Establishment_Year_2007       192.29
# Outlet_Establishment_Year_2009       -37.56
# Outlet_Size_Medium                   620.58
# Outlet_Size_Missing                 -436.47
# Outlet_Size_Small                   -288.73
# Outlet_Location_Type_Tier 2          423.53
# Outlet_Location_Type_Tier 3          128.50
# Outlet_Type_Supermarket Type1        652.56
# Outlet_Type_Supermarket Type2        -37.56
# Outlet_Type_Supermarket Type3        798.89
# intercept                          2,570.04
# dtype: float64

# %%
def plot_coeffs(coeffs, top_n=None,  figsize=(4,5), 
                intercept=False,  intercept_name = "intercept", 
                annotate=False, ha='left',va='center', size=12, 
                xytext=(4,0), textcoords='offset points'):
    """ Plots the top_n coefficients from a Series, with optional annotations.
    """
    # Drop intercept if intercept=False and 
    if (intercept==False) & ( intercept_name in coeffs.index):
        coeffs = coeffs.drop(intercept_name)
    if top_n==None:
        ## sort all features and set title
        plot_vals = coeffs#.sort_values()
        title = "All Coefficients - Ranked by Magnitude"
    else:
        ## rank the coeffs and select the top_n
        coeff_rank = coeffs.abs().rank().sort_values(ascending=False)
        top_n_features = coeff_rank.head(top_n)
        
        ## sort features and keep top_n and set title
        plot_vals = coeffs.loc[top_n_features.index].sort_values()
        title = f"Top {top_n} Largest Coefficients"
    ## plotting top N importances
    ax = plot_vals.plot(kind='barh', figsize=figsize)
    ax.set(xlabel='Coefficient', 
            ylabel='Feature Names', 
            title=title)
    ax.axvline(0, color='k')
    if annotate==True:
        annotate_hbars(ax, ha=ha,va=va,size=size,xytext=xytext, textcoords=textcoords)
    return ax

# %%
def annotate_hbars(ax, ha='left',va='center',size=12,  xytext=(4,0),
                  textcoords='offset points'):
    for bar in ax.patches:
    
        ## calculate center of bar
        bar_ax = bar.get_y() + bar.get_height()/2
        ## get the value to annotate
        val = bar.get_width()
        if val < 0:
            val_pos = 0
        else:
            val_pos = val
        # ha and va stand for the horizontal and vertical alignment
        ax.annotate(f"{val:.3f}", (val_pos,bar_ax), ha=ha,va=va,size=size,
                        xytext=xytext, textcoords=textcoords)

# %%
ax = plot_coeffs(coeffs,top_n=3, annotate = True)

# %% [markdown]
# All Item Identifiers correlate to a single, one hot encoded item. They signify a change in X dollars (where X is the coefficient) depending on the item. For example, if an item is FDU55, then it will be 6640.594 monetary units to start with.

# %%
#Saving Figure
plt.savefig("LineReg3MIF.png")

# %% [markdown]
# ### REGRESSION TREE MODEL
#
# Evaluate the performance of your model based on r^2 and RMSE

# %%
#model instance
dec_tree = DecisionTreeRegressor(random_state = 42)

#fitting the model
dec_tree.fit(X_train_df, y_train)

#prediction values
dec_train_preds = dec_tree.predict(X_train_df)
dec_test_preds = dec_tree.predict(X_test_df)

#model evaluation
dec_train_score = dec_tree.score(X_train_df, y_train)
dec_test_score = dec_tree.score(X_test_df, y_test)
print(dec_train_score)
print(dec_test_score)
# Out:
# 1.0
# 0.23404827503951597

# %%
#Decision Tree Tuning
depth = dec_tree.get_depth()
# List of values to try for max_depth:
depths = list(range(1, depth))
# Data frame to store the score for each value of max_depth:
scores = pd.DataFrame(index=depths, columns=['Test Score','Train Score'])
for depth in depths:
    dec_tree = DecisionTreeRegressor(max_depth=depth, random_state=42)
    dec_tree.fit(X_train_df, y_train)
    train_score = dec_tree.score(X_train_df, y_train)
    test_score = dec_tree.score(X_test_df, y_test)
    scores.loc[depth, 'Train Score'] = train_score
    scores.loc[depth, 'Test Score'] = test_score

sorted_scores = scores.sort_values(by='Test Score', ascending=False)
sorted_scores.head()
# Out:
#   Test Score Train Score
# 5       0.59        0.61
# 6       0.58        0.63
# 4       0.58        0.58
# 7       0.57        0.64
# 8       0.56        0.65

# %%
#Decision Tree Tuning 2; optimal depth = 5
optimal_depth = 5

dec_tree_opt = DecisionTreeRegressor(max_depth = optimal_depth, random_state = 42)
dec_tree_opt.fit(X_train_df, y_train)
evaluate_regression(dec_tree_opt, X_train_df, y_train, X_test_df, y_test)
# Out:
# Training Data:	R^2= 0.61	RMSE= 1071.25
# Test Data:	R^2= 0.59	RMSE= 1065.01

# %%
#Extracting feature importances into pandas series
importances = pd.Series(dec_tree_opt.feature_importances_, index= feature_names,
                       name='Feature Importance')
importances = importances.sort_values(ascending = True)
importances.tail()
# Out:
# Item_Identifier_DRB01           0.00
# Outlet_Identifier_OUT018        0.11
# Outlet_Type_Supermarket Type1   0.16
# Outlet_Identifier_OUT027        0.18
# Item_MRP                        0.55
# Name: Feature Importance, dtype: float64

# %%
#Making sure importances = 1
importances.sum()
# Out:
# 1.0

# %%
#Graphing top 5 importances
## just keep the top 10 importances and plot
ax = importances.tail(5).plot(kind='barh',
                         figsize=(8,6),
                        title = "Top 5 Most Important Features",
                        xlabel = "Importance",
                        ylabel = "Feature Name")
fig_gcf = plt.gcf()

# %%
#Saving Figure
plt.savefig("DecTree5MIF.png")

# %% [markdown]
# ### Keras Deep Learning Model

# %%
# Learning history plotting function
def plot_history(history):
  """Takes a keras model learning history and plots each metric"""
  metrics = history.history.keys()
  for metric in metrics:
      if not 'val' in metric:
        plt.plot(history.history[f'{metric}'], label=f'{metric}')
        if f'val_{metric}' in metrics:
          plt.plot(history.history[f'val_{metric}'], label=f'val_{metric}')
        plt.legend()
        plt.title(f'{metric}')
        plt.show()

# %%
# create model architecture
input_shape = X_train_df.shape[1]
 
reg_model = Sequential()
 
reg_model.add(Dense(10, input_dim=input_shape, activation='relu'))
reg_model.add(Dense(10, activation='relu'))
reg_model.add(Dense(1, activation='linear'))
 
reg_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 10)                15940
#
#  dense_1 (Dense)             (None, 10)                110
#
#  dense_2 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 16,061
# Trainable params: 16,061
# Non-trainable params: 0
# _________________________________________________________________
# 2023-04-21 00:04:05.049780: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# compile model with additional metrics 
reg_model.compile(loss='mse',
                  optimizer='adam',
                  metrics=[metrics.RootMeanSquaredError()])

# %%
#X_train_array = X_train_df.toarray()
#X_test_array = X_test_df.toarray()

history = reg_model.fit(X_train_df, y_train,
                        validation_data = (X_test_df, y_test),
                        epochs=100,
                        verbose=0)

# %%
# plot learning
plot_history(history)

# %%
# evaluate model
 
y_pred = reg_model.predict(X_test_df)
 
evaluate_regression(reg_model, X_train_df, y_train, X_test_df, y_test)
# Out:
# 67/67 [==============================] - 0s 1ms/step
# 200/200 [==============================] - 0s 983us/step
# Training Data:	R^2= 0.63	RMSE= 1042.72
# 67/67 [==============================] - 0s 1ms/step
# Test Data:	R^2= 0.59	RMSE= 1067.63

# %% [markdown]
# ## Which model to use?
#
#
# <center>Linear Regression:</center>
#
# |                | r^2                 | RMSE               |
# |----------------|---------------------|--------------------|
# | Model Training | 0.6716977904733816  | 985.6956156908806  |
# | Model Testing  | 0.38335523332222055 | 1304.3423269636032 |
#
# <center> Decision Tree:</center>
#
# |                | r^2                 | RMSE               |
# |----------------|---------------------|--------------------|
# | Model Training | 0.6716977904733816  | 1082.281287111312  |
# | Model Testing  | 0.38335523332222055 | 1055.6851402178304 |
#
# Keras TensorFlow:
#
# Model Testing r^2:  0.5441030783172758
#
# Model Testing RMSE: 1121.5209549997742

# %% [markdown]
# The r^2 values for both the linear regression and the decision tree are the same. The r^2 value for the tensorflow though was lower, so we can eliminate that model for use.The RMSE values for the Linear Regression and Decision tree are different. Because the RMSE for the test on the decision tree is lower than the RMSE for the test on the regression, I recommend the Decision Tree in order to avoid larger errors.

# %% [markdown]
# ### Serializing Final Model
#
# Once you've finished updating and explaining your models, you must save the following key: value pairs as a dictionary in a joblib file named "best-models.joblib":
# * "preprocessor": your preprocessing  column transformer
# * "X_train": your training features.
# * "X_test": your test features.
# * "y_train": your training target.
# * "y_test": your test target.
# * "LinearRegression": your best linear regression
# * Your tree-based model's class name: your best tree-based model. e.g. "RandomForestRegressor"/"DecisionTreeRegressor"
#
# Save your joblib file inside your repository. (You will work with these models again in the next core assignment.)

# %%
## creating a dictionary of all of the variables to save for later
export = {'X_train':X_train_df,
         'y_train': y_train,
         'X_test':X_test_df,
          "y_test": y_test,
         'preprocessor':preprocessor,
          "LinearRegression": reg,
         'DecisionTree':dec_tree_opt}
joblib.dump(export, 'dec_tree.joblib')
# Out:
# ['dec_tree.joblib']
